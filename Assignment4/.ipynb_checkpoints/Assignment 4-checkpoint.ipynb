# %% [markdown]
# # Assignment 4 - Helper Functions
# We begin by including the functions to generate frequent itemsets (via the Apriori algorithm) and resulting association rules:

# %%
# (c) 2016 Everaldo Aguiar & Reid Johnson
#
# Modified from:
# Marcel Caraciolo (https://gist.github.com/marcelcaraciolo/1423287)
# Functions to compute and extract association rules from a given frequent itemset 
# generated by the Apriori algorithm.
#
# The Apriori algorithm is defined by Agrawal and Srikant in:
# Fast algorithms for mining association rules
# Proc. 20th int. conf. very large data bases, VLDB. Vol. 1215. 1994
import csv
import numpy as np

def load_dataset(filename):
    '''Loads an example of market basket transactions from a provided csv file.

    Returns: A list (database) of lists (transactions). Each element of a transaction is 
    an item.
    '''

    with open(filename,'r') as dest_f:
        data_iter = csv.reader(dest_f, delimiter = ',', quotechar = '"')
        data = [data for data in data_iter]
        data_array = np.asarray(data)
        
    return data_array

def apriori(dataset, min_support=0.5, verbose=False):
    """Implements the Apriori algorithm.

    The Apriori algorithm will iteratively generate new candidate 
    k-itemsets using the frequent (k-1)-itemsets found in the previous 
    iteration.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    Returns
    -------
    F : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.

    References
    ----------
    .. [1] R. Agrawal, R. Srikant, "Fast Algorithms for Mining Association 
           Rules", 1994.

    """
    C1 = create_candidates(dataset)
    D = list(map(set, dataset))
    F1, support_data = support_prune(D, C1, min_support, verbose=False) # prune candidate 1-itemsets
    F = [F1] # list of frequent itemsets; initialized to frequent 1-itemsets
    k = 2 # the itemset cardinality
    while (len(F[k - 2]) > 0):
        Ck = apriori_gen(F[k-2], k) # generate candidate itemsets
        Fk, supK = support_prune(D, Ck, min_support) # prune candidate itemsets
        support_data.update(supK) # update the support counts to reflect pruning
        F.append(Fk) # add the pruned candidate itemsets to the list of frequent itemsets
        k += 1

    if verbose:
        # Print a list of all the frequent itemsets.
        for kset in F:
            for item in kset:
                print("" \
                    + "{" \
                    + "".join(str(i) + ", " for i in iter(item)).rstrip(', ') \
                    + "}" \
                    + ":  sup = " + str(round(support_data[item], 3)))

    return F, support_data

def create_candidates(dataset, verbose=False):
    """Creates a list of candidate 1-itemsets from a list of transactions.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    Returns
    -------
    The list of candidate itemsets (c1) passed as a frozenset (a set that is 
    immutable and hashable).
    """
    c1 = [] # list of all items in the database of transactions
    for transaction in dataset:
        for item in transaction:
            if not [item] in c1:
                c1.append([item])
    c1.sort()

    if verbose:
        # Print a list of all the candidate items.
        print("" \
            + "{" \
            + "".join(str(i[0]) + ", " for i in iter(c1)).rstrip(', ') \
            + "}")

    # Map c1 to a frozenset because it will be the key of a dictionary.
    return list(map(frozenset, c1))

def support_prune(dataset, candidates, min_support, verbose=False):
    """Returns all candidate itemsets that meet a minimum support threshold.

    By the apriori principle, if an itemset is frequent, then all of its 
    subsets must also be frequent. As a result, we can perform support-based 
    pruning to systematically control the exponential growth of candidate 
    itemsets. Thus, itemsets that do not meet the minimum support level are 
    pruned from the input list of itemsets (dataset).

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    candidates : frozenset
        The list of candidate itemsets.

    min_support : float
        The minimum support threshold.

    Returns
    -------
    retlist : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.
    """
    sscnt = {} # set for support counts
    for tid in dataset:
        for can in candidates:
            if can.issubset(tid):
                sscnt.setdefault(can, 0)
                sscnt[can] += 1

    num_items = float(len(dataset)) # total number of transactions in the dataset
    retlist = [] # array for unpruned itemsets
    support_data = {} # set for support data for corresponding itemsets
    for key in sscnt:
        # Calculate the support of itemset key.
        support = sscnt[key] / num_items
        if support >= min_support:
            retlist.insert(0, key)
        support_data[key] = support

    # Print a list of the pruned itemsets.
    if verbose:
        for kset in retlist:
            for item in kset:
                print("{" + str(item) + "}")
        print("")
        for key in sscnt:
            print("" \
                + "{" \
                + "".join([str(i) + ", " for i in iter(key)]).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(support_data[key]))

    return retlist, support_data

def apriori_gen(freq_sets, k):
    """Generates candidate itemsets (via the F_k-1 x F_k-1 method).

    This operation generates new candidate k-itemsets based on the frequent 
    (k-1)-itemsets found in the previous iteration. The candidate generation 
    procedure merges a pair of frequent (k-1)-itemsets only if their first k-2 
    items are identical.

    Parameters
    ----------
    freq_sets : list
        The list of frequent (k-1)-itemsets.

    k : integer
        The cardinality of the current itemsets being evaluated.

    Returns
    -------
    retlist : list
        The list of merged frequent itemsets.
    """
    retList = [] # list of merged frequent itemsets
    lenLk = len(freq_sets) # number of frequent itemsets
    for i in range(lenLk):
        for j in range(i+1, lenLk):
            a=list(freq_sets[i])
            b=list(freq_sets[j])
            a.sort()
            b.sort()
            F1 = a[:k-2] # first k-2 items of freq_sets[i]
            F2 = b[:k-2] # first k-2 items of freq_sets[j]

            if F1 == F2: # if the first k-2 items are identical
                # Merge the frequent itemsets.
                retList.append(freq_sets[i] | freq_sets[j])

    return retList

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1, support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([itemset]) for itemset in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# %%
#loading grocery dataset

# %%
dataset = load_dataset('grocery.csv')
D = list(map(set, dataset))
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
type(dataset)
# Out:
# numpy.ndarray

# %%
dataset.shape
# Out:
# (9835,)

# %%
dataset[0]
# Out:
# ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups']

# %%
dataset[1]
# Out:
# ['tropical fruit', 'yogurt', 'coffee']

# %%
type(D[0])
# Out:
# set

# %%
D[0]
# Out:
# {'citrus fruit', 'margarine', 'ready soups', 'semi-finished bread'}

# %% [markdown]
# # Part 1 - Apriori

# %%
#generating candidate itemsets - using create_candidates function.
Candidates = create_candidates(dataset, verbose=True)
# Out:
# {Instant food products, UHT-milk, abrasive cleaner, artif. sweetener, baby cosmetics, baby food, bags, baking powder, bathroom cleaner, beef, berries, beverages, bottled beer, bottled water, brandy, brown bread, butter, butter milk, cake bar, candles, candy, canned beer, canned fish, canned fruit, canned vegetables, cat food, cereals, chewing gum, chicken, chocolate, chocolate marshmallow, citrus fruit, cleaner, cling film/bags, cocoa drinks, coffee, condensed milk, cooking chocolate, cookware, cream, cream cheese , curd, curd cheese, decalcifier, dental care, dessert, detergent, dish cleaner, dishes, dog food, domestic eggs, female sanitary products, finished products, fish, flour, flower (seeds), flower soil/fertilizer, frankfurter, frozen chicken, frozen dessert, frozen fish, frozen fruits, frozen meals, frozen potato products, frozen vegetables, fruit/vegetable juice, grapes, hair spray, ham, hamburger meat, hard cheese, herbs, honey, house keeping products, hygiene articles, ice cream, instant coffee, jam, ketchup, kitchen towels, kitchen utensil, light bulbs, liqueur, liquor, liquor (appetizer), liver loaf, long life bakery product, make up remover, male cosmetics, margarine, mayonnaise, meat, meat spreads, misc. beverages, mustard, napkins, newspapers, nut snack, nuts/prunes, oil, onions, organic products, organic sausage, other vegetables, packaged fruit/vegetables, pasta, pastry, pet care, photo/film, pickled vegetables, pip fruit, popcorn, pork, pot plants, potato products, preservation products, processed cheese, prosecco, pudding powder, ready soups, red/blush wine, rice, roll products , rolls/buns, root vegetables, rubbing alcohol, rum, salad dressing, salt, salty snack, sauces, sausage, seasonal products, semi-finished bread, shopping bags, skin care, sliced cheese, snack products, soap, soda, soft cheese, softener, sound storage medium, soups, sparkling wine, specialty bar, specialty cheese, specialty chocolate, specialty fat, specialty vegetables, spices, spread cheese, sugar, sweet spreads, syrup, tea, tidbits, toilet cleaner, tropical fruit, turkey, vinegar, waffles, whipped/sour cream, whisky, white bread, white wine, whole milk, yogurt, zwieback}

# %% [markdown]
# the create_candidates function creates a list of candidate 1-itemsets from a list of transactions.

# %%
# generating candidate itemsets with support - using support_prune
Candidates_SP = support_prune(D, Candidates, 0.4, verbose=True)
# Out:
# {citrus fruit}:  sup = 0.08276563294356888
# {margarine}:  sup = 0.05856634468734113
# {ready soups}:  sup = 0.0018301982714794102
# {semi-finished bread}:  sup = 0.017691916624300967
# {coffee}:  sup = 0.05805795627859685
# {tropical fruit}:  sup = 0.10493136756481952
# {yogurt}:  sup = 0.13950177935943062
# {whole milk}:  sup = 0.25551601423487547
# {cream cheese}:  sup = 0.03965429588205389
# {meat spreads}:  sup = 0.004270462633451958
# {pip fruit}:  sup = 0.07564819522114896
# {condensed milk}:  sup = 0.010269445856634469
# {long life bakery product}:  sup = 0.037417386883579054
# {other vegetables}:  sup = 0.1934926283680732
# {abrasive cleaner}:  sup = 0.0035587188612099642
# {butter}:  sup = 0.05541433655312659
# {rice}:  sup = 0.007625826131164209
# {rolls/buns}:  sup = 0.18393492628368074
# {UHT-milk}:  sup = 0.03345195729537367
# {bottled beer}:  sup = 0.08052872394509406
# {liquor (appetizer)}:  sup = 0.007930859176410779
# {pot plants}:  sup = 0.01728520589730554
# {cereals}:  sup = 0.0056939501779359435
# {bottled water}:  sup = 0.11052364006100661
# {chocolate}:  sup = 0.04961870869344179
# {white bread}:  sup = 0.042094560244026434
# {curd}:  sup = 0.05327910523640061
# {dishes}:  sup = 0.01759023894255211
# {flour}:  sup = 0.017386883579054397
# {beef}:  sup = 0.05246568378240976
# {frankfurter}:  sup = 0.058973055414336555
# {soda}:  sup = 0.17437722419928825
# {chicken}:  sup = 0.04290798169801729
# {fruit/vegetable juice}:  sup = 0.0722928317234367
# {newspapers}:  sup = 0.07981698017285206
# {sugar}:  sup = 0.03385866802236909
# {packaged fruit/vegetables}:  sup = 0.013014743263853584
# {specialty bar}:  sup = 0.027351296390442297
# {butter milk}:  sup = 0.027961362480935434
# {pastry}:  sup = 0.08896797153024912
# {detergent}:  sup = 0.019217081850533807
# {processed cheese}:  sup = 0.016573462125063547
# {bathroom cleaner}:  sup = 0.0027452974072191155
# {candy}:  sup = 0.0298932384341637
# {frozen dessert}:  sup = 0.010777834265378749
# {root vegetables}:  sup = 0.10899847483477376
# {salty snack}:  sup = 0.03782409761057448
# {sweet spreads}:  sup = 0.009049313675648195
# {waffles}:  sup = 0.038434163701067614
# {canned beer}:  sup = 0.07768174885612608
# {sausage}:  sup = 0.09395017793594305
# {brown bread}:  sup = 0.06487036095577021
# {shopping bags}:  sup = 0.09852567361464158
# {beverages}:  sup = 0.026029486527707167
# {hamburger meat}:  sup = 0.033248601931875954
# {hygiene articles}:  sup = 0.03294356888662939
# {napkins}:  sup = 0.05236400610066091
# {spices}:  sup = 0.005185561769191663
# {artif. sweetener}:  sup = 0.003253685815963396
# {berries}:  sup = 0.033248601931875954
# {pork}:  sup = 0.05765124555160142
# {whipped/sour cream}:  sup = 0.07168276563294357
# {grapes}:  sup = 0.022369089984748347
# {dessert}:  sup = 0.03711235383833249
# {zwieback}:  sup = 0.006914082358922217
# {domestic eggs}:  sup = 0.06344687341128623
# {spread cheese}:  sup = 0.011184544992374174
# {misc. beverages}:  sup = 0.02836807320793086
# {hard cheese}:  sup = 0.024504321301474327
# {cat food}:  sup = 0.023284189120488054
# {ham}:  sup = 0.026029486527707167
# {baking powder}:  sup = 0.017691916624300967
# {turkey}:  sup = 0.00813421453990849
# {pickled vegetables}:  sup = 0.017895271987798677
# {chewing gum}:  sup = 0.021047280122013217
# {chocolate marshmallow}:  sup = 0.009049313675648195
# {oil}:  sup = 0.02806304016268429
# {ice cream}:  sup = 0.025012709710218607
# {canned fish}:  sup = 0.015048296898830707
# {frozen vegetables}:  sup = 0.04809354346720895
# {seasonal products}:  sup = 0.014234875444839857
# {curd cheese}:  sup = 0.005083884087442806
# {red/blush wine}:  sup = 0.019217081850533807
# {frozen potato products}:  sup = 0.008439247585155059
# {candles}:  sup = 0.008947635993899338
# {flower (seeds)}:  sup = 0.010371123538383325
# {specialty chocolate}:  sup = 0.03040162684290798
# {specialty fat}:  sup = 0.0036603965429588205
# {sparkling wine}:  sup = 0.005592272496187087
# {salt}:  sup = 0.010777834265378749
# {frozen meals}:  sup = 0.02836807320793086
# {canned vegetables}:  sup = 0.010777834265378749
# {onions}:  sup = 0.031011692933401117
# {herbs}:  sup = 0.01626842907981698
# {white wine}:  sup = 0.019013726487036097
# {brandy}:  sup = 0.004168784951703101
# {photo/film}:  sup = 0.009252669039145907
# {sliced cheese}:  sup = 0.024504321301474327
# {pasta}:  sup = 0.015048296898830707
# {softener}:  sup = 0.005490594814438231
# {cling film/bags}:  sup = 0.011387900355871887
# {fish}:  sup = 0.0029486527707168276
# {male cosmetics}:  sup = 0.004575495678698526
# {canned fruit}:  sup = 0.003253685815963396
# {Instant food products}:  sup = 0.008032536858159633
# {soft cheese}:  sup = 0.01708185053380783
# {honey}:  sup = 0.001525165226232842
# {dental care}:  sup = 0.005795627859684799
# {popcorn}:  sup = 0.007219115404168785
# {cake bar}:  sup = 0.013218098627351297
# {snack products}:  sup = 0.003050330452465684
# {flower soil/fertilizer}:  sup = 0.0019318759532282665
# {specialty cheese}:  sup = 0.008540925266903915
# {finished products}:  sup = 0.006507371631926792
# {cocoa drinks}:  sup = 0.0022369089984748346
# {dog food}:  sup = 0.008540925266903915
# {prosecco}:  sup = 0.0020335536349771225
# {frozen fish}:  sup = 0.011692933401118455
# {make up remover}:  sup = 0.000813421453990849
# {cleaner}:  sup = 0.005083884087442806
# {female sanitary products}:  sup = 0.006100660904931368
# {cookware}:  sup = 0.0027452974072191155
# {dish cleaner}:  sup = 0.01047280122013218
# {meat}:  sup = 0.025826131164209457
# {tea}:  sup = 0.003863751906456533
# {mustard}:  sup = 0.011997966446365024
# {house keeping products}:  sup = 0.008337569903406202
# {skin care}:  sup = 0.0035587188612099642
# {potato products}:  sup = 0.0028469750889679717
# {liquor}:  sup = 0.011082867310625319
# {pet care}:  sup = 0.00945602440264362
# {soups}:  sup = 0.00681240467717336
# {rum}:  sup = 0.004473817996949669
# {salad dressing}:  sup = 0.000813421453990849
# {sauces}:  sup = 0.005490594814438231
# {vinegar}:  sup = 0.006507371631926792
# {soap}:  sup = 0.0026436197254702592
# {hair spray}:  sup = 0.0011184544992374173
# {instant coffee}:  sup = 0.007422470767666497
# {roll products}:  sup = 0.010269445856634469
# {mayonnaise}:  sup = 0.009150991357397052
# {rubbing alcohol}:  sup = 0.0010167768174885613
# {syrup}:  sup = 0.003253685815963396
# {liver loaf}:  sup = 0.005083884087442806
# {baby cosmetics}:  sup = 0.0006100660904931368
# {organic products}:  sup = 0.001626842907981698
# {nut snack}:  sup = 0.00315200813421454
# {kitchen towels}:  sup = 0.005998983223182512
# {frozen chicken}:  sup = 0.0006100660904931368
# {light bulbs}:  sup = 0.004168784951703101
# {ketchup}:  sup = 0.004270462633451958
# {jam}:  sup = 0.005388917132689374
# {decalcifier}:  sup = 0.001525165226232842
# {nuts/prunes}:  sup = 0.003355363497712252
# {liqueur}:  sup = 0.0009150991357397051
# {organic sausage}:  sup = 0.0022369089984748346
# {cream}:  sup = 0.0013218098627351296
# {toilet cleaner}:  sup = 0.0007117437722419929
# {specialty vegetables}:  sup = 0.0017285205897305542
# {baby food}:  sup = 0.00010167768174885612
# {pudding powder}:  sup = 0.002338586680223691
# {tidbits}:  sup = 0.002338586680223691
# {whisky}:  sup = 0.000813421453990849
# {frozen fruits}:  sup = 0.0012201321809862736
# {bags}:  sup = 0.0004067107269954245
# {cooking chocolate}:  sup = 0.002541942043721403
# {sound storage medium}:  sup = 0.00010167768174885612
# {kitchen utensil}:  sup = 0.0004067107269954245
# {preservation products}:  sup = 0.00020335536349771224

# %% [markdown]
# support_prune returns all candidate item sets that meet a minimum support threshold

# %%
#selecting those that are frequent using Apriori - experimenting with min_support parameter.
Fi,Frequent_items = apriori(dataset, min_support=0.01, verbose=True)
# Out:
# {roll products}:  sup = 0.01
# {liquor}:  sup = 0.011
# {mustard}:  sup = 0.012
# {meat}:  sup = 0.026
# {dish cleaner}:  sup = 0.01
# {frozen fish}:  sup = 0.012
# {cake bar}:  sup = 0.013
# {soft cheese}:  sup = 0.017
# {cling film/bags}:  sup = 0.011
# {pasta}:  sup = 0.015
# {sliced cheese}:  sup = 0.025
# {white wine}:  sup = 0.019
# {herbs}:  sup = 0.016
# {onions}:  sup = 0.031
# {canned vegetables}:  sup = 0.011
# {frozen meals}:  sup = 0.028
# {salt}:  sup = 0.011
# {specialty chocolate}:  sup = 0.03
# {flower (seeds)}:  sup = 0.01
# {red/blush wine}:  sup = 0.019
# {seasonal products}:  sup = 0.014
# {frozen vegetables}:  sup = 0.048
# {canned fish}:  sup = 0.015
# {ice cream}:  sup = 0.025
# {oil}:  sup = 0.028
# {chewing gum}:  sup = 0.021
# {pickled vegetables}:  sup = 0.018
# {baking powder}:  sup = 0.018
# {ham}:  sup = 0.026
# {cat food}:  sup = 0.023
# {hard cheese}:  sup = 0.025
# {misc. beverages}:  sup = 0.028
# {spread cheese}:  sup = 0.011
# {domestic eggs}:  sup = 0.063
# {dessert}:  sup = 0.037
# {grapes}:  sup = 0.022
# {whipped/sour cream}:  sup = 0.072
# {pork}:  sup = 0.058
# {berries}:  sup = 0.033
# {napkins}:  sup = 0.052
# {hygiene articles}:  sup = 0.033
# {hamburger meat}:  sup = 0.033
# {beverages}:  sup = 0.026
# {shopping bags}:  sup = 0.099
# {brown bread}:  sup = 0.065
# {sausage}:  sup = 0.094
# {canned beer}:  sup = 0.078
# {waffles}:  sup = 0.038
# {salty snack}:  sup = 0.038
# {root vegetables}:  sup = 0.109
# {frozen dessert}:  sup = 0.011
# {candy}:  sup = 0.03
# {processed cheese}:  sup = 0.017
# {detergent}:  sup = 0.019
# {pastry}:  sup = 0.089
# {butter milk}:  sup = 0.028
# {specialty bar}:  sup = 0.027
# {packaged fruit/vegetables}:  sup = 0.013
# {sugar}:  sup = 0.034
# {newspapers}:  sup = 0.08
# {fruit/vegetable juice}:  sup = 0.072
# {chicken}:  sup = 0.043
# {soda}:  sup = 0.174
# {frankfurter}:  sup = 0.059
# {beef}:  sup = 0.052
# {flour}:  sup = 0.017
# {dishes}:  sup = 0.018
# {curd}:  sup = 0.053
# {white bread}:  sup = 0.042
# {chocolate}:  sup = 0.05
# {bottled water}:  sup = 0.111
# {pot plants}:  sup = 0.017
# {bottled beer}:  sup = 0.081
# {UHT-milk}:  sup = 0.033
# {rolls/buns}:  sup = 0.184
# {butter}:  sup = 0.055
# {other vegetables}:  sup = 0.193
# {long life bakery product}:  sup = 0.037
# {condensed milk}:  sup = 0.01
# {pip fruit}:  sup = 0.076
# {cream cheese}:  sup = 0.04
# {whole milk}:  sup = 0.256
# {yogurt}:  sup = 0.14
# {tropical fruit}:  sup = 0.105
# {coffee}:  sup = 0.058
# {semi-finished bread}:  sup = 0.018
# {margarine}:  sup = 0.059
# {citrus fruit}:  sup = 0.083
# {margarine, soda}:  sup = 0.01
# {newspapers, root vegetables}:  sup = 0.011
# {white bread, soda}:  sup = 0.01
# {coffee, rolls/buns}:  sup = 0.011
# {beef, yogurt}:  sup = 0.012
# {pastry, pip fruit}:  sup = 0.011
# {chicken, whole milk}:  sup = 0.018
# {margarine, yogurt}:  sup = 0.014
# {pip fruit, soda}:  sup = 0.013
# {tropical fruit, napkins}:  sup = 0.01
# {onions, whole milk}:  sup = 0.012
# {onions, other vegetables}:  sup = 0.014
# {citrus fruit, soda}:  sup = 0.013
# {other vegetables, newspapers}:  sup = 0.019
# {bottled water, pip fruit}:  sup = 0.011
# {sausage, bottled water}:  sup = 0.012
# {soda, napkins}:  sup = 0.012
# {root vegetables, shopping bags}:  sup = 0.013
# {other vegetables, beef}:  sup = 0.02
# {other vegetables, butter milk}:  sup = 0.01
# {pork, root vegetables}:  sup = 0.014
# {tropical fruit, shopping bags}:  sup = 0.014
# {cream cheese , other vegetables}:  sup = 0.014
# {frankfurter, yogurt}:  sup = 0.011
# {pip fruit, root vegetables}:  sup = 0.016
# {whipped/sour cream, tropical fruit}:  sup = 0.014
# {whipped/sour cream, yogurt}:  sup = 0.021
# {whole milk, sliced cheese}:  sup = 0.011
# {bottled water, shopping bags}:  sup = 0.011
# {white bread, whole milk}:  sup = 0.017
# {frozen vegetables, yogurt}:  sup = 0.012
# {other vegetables, yogurt}:  sup = 0.043
# {citrus fruit, rolls/buns}:  sup = 0.017
# {other vegetables, pip fruit}:  sup = 0.026
# {citrus fruit, pip fruit}:  sup = 0.014
# {citrus fruit, fruit/vegetable juice}:  sup = 0.01
# {sausage, citrus fruit}:  sup = 0.011
# {sausage, tropical fruit}:  sup = 0.014
# {sausage, pip fruit}:  sup = 0.011
# {hygiene articles, whole milk}:  sup = 0.013
# {hard cheese, whole milk}:  sup = 0.01
# {coffee, other vegetables}:  sup = 0.013
# {other vegetables, pastry}:  sup = 0.023
# {other vegetables, shopping bags}:  sup = 0.023
# {pastry, shopping bags}:  sup = 0.012
# {cream cheese , whole milk}:  sup = 0.016
# {whole milk, hamburger meat}:  sup = 0.015
# {margarine, bottled water}:  sup = 0.01
# {frankfurter, other vegetables}:  sup = 0.016
# {frankfurter, root vegetables}:  sup = 0.01
# {sausage, other vegetables}:  sup = 0.027
# {sausage, frankfurter}:  sup = 0.01
# {beef, root vegetables}:  sup = 0.017
# {bottled beer, whole milk}:  sup = 0.02
# {fruit/vegetable juice, yogurt}:  sup = 0.019
# {yogurt, shopping bags}:  sup = 0.015
# {whole milk, shopping bags}:  sup = 0.025
# {yogurt, napkins}:  sup = 0.012
# {whole milk, napkins}:  sup = 0.02
# {pork, rolls/buns}:  sup = 0.011
# {citrus fruit, other vegetables}:  sup = 0.029
# {chicken, other vegetables}:  sup = 0.018
# {citrus fruit, root vegetables}:  sup = 0.018
# {chicken, root vegetables}:  sup = 0.011
# {sausage, fruit/vegetable juice}:  sup = 0.01
# {brown bread, sausage}:  sup = 0.011
# {citrus fruit, whipped/sour cream}:  sup = 0.011
# {sausage, yogurt}:  sup = 0.02
# {sausage, root vegetables}:  sup = 0.015
# {margarine, rolls/buns}:  sup = 0.015
# {whole milk, fruit/vegetable juice}:  sup = 0.027
# {fruit/vegetable juice, rolls/buns}:  sup = 0.015
# {margarine, root vegetables}:  sup = 0.011
# {fruit/vegetable juice, root vegetables}:  sup = 0.012
# {domestic eggs, rolls/buns}:  sup = 0.016
# {frozen vegetables, rolls/buns}:  sup = 0.01
# {frozen vegetables, root vegetables}:  sup = 0.012
# {bottled beer, soda}:  sup = 0.017
# {bottled beer, bottled water}:  sup = 0.016
# {bottled water, fruit/vegetable juice}:  sup = 0.014
# {whole milk, butter milk}:  sup = 0.012
# {frankfurter, whole milk}:  sup = 0.021
# {whole milk, newspapers}:  sup = 0.027
# {citrus fruit, domestic eggs}:  sup = 0.01
# {oil, whole milk}:  sup = 0.011
# {margarine, whole milk}:  sup = 0.024
# {tropical fruit, pip fruit}:  sup = 0.02
# {whole milk, pip fruit}:  sup = 0.03
# {whole milk, rolls/buns}:  sup = 0.057
# {pip fruit, rolls/buns}:  sup = 0.014
# {whole milk, chocolate}:  sup = 0.017
# {brown bread, rolls/buns}:  sup = 0.013
# {whole milk, beef}:  sup = 0.021
# {sausage, whole milk}:  sup = 0.03
# {sausage, pastry}:  sup = 0.013
# {salty snack, whole milk}:  sup = 0.011
# {frozen vegetables, whole milk}:  sup = 0.02
# {frozen vegetables, other vegetables}:  sup = 0.018
# {pastry, rolls/buns}:  sup = 0.021
# {beef, rolls/buns}:  sup = 0.014
# {margarine, other vegetables}:  sup = 0.02
# {tropical fruit, fruit/vegetable juice}:  sup = 0.014
# {other vegetables, fruit/vegetable juice}:  sup = 0.021
# {brown bread, other vegetables}:  sup = 0.019
# {domestic eggs, other vegetables}:  sup = 0.022
# {ham, whole milk}:  sup = 0.011
# {butter, other vegetables}:  sup = 0.02
# {butter, rolls/buns}:  sup = 0.013
# {other vegetables, curd}:  sup = 0.017
# {rolls/buns, curd}:  sup = 0.01
# {butter, root vegetables}:  sup = 0.013
# {bottled water, root vegetables}:  sup = 0.016
# {curd, root vegetables}:  sup = 0.011
# {butter, whipped/sour cream}:  sup = 0.01
# {whipped/sour cream, rolls/buns}:  sup = 0.015
# {whipped/sour cream, curd}:  sup = 0.01
# {whipped/sour cream, root vegetables}:  sup = 0.017
# {yogurt, rolls/buns}:  sup = 0.034
# {bottled water, soda}:  sup = 0.029
# {newspapers, yogurt}:  sup = 0.015
# {newspapers, rolls/buns}:  sup = 0.02
# {bottled water, newspapers}:  sup = 0.011
# {berries, yogurt}:  sup = 0.011
# {whole milk, coffee}:  sup = 0.019
# {tropical fruit, soda}:  sup = 0.021
# {yogurt, soda}:  sup = 0.027
# {tropical fruit, pastry}:  sup = 0.013
# {pastry, yogurt}:  sup = 0.018
# {whole milk, pastry}:  sup = 0.033
# {yogurt, root vegetables}:  sup = 0.026
# {soda, root vegetables}:  sup = 0.019
# {pastry, root vegetables}:  sup = 0.011
# {whole milk, waffles}:  sup = 0.013
# {brown bread, tropical fruit}:  sup = 0.011
# {brown bread, yogurt}:  sup = 0.015
# {brown bread, whole milk}:  sup = 0.025
# {brown bread, root vegetables}:  sup = 0.01
# {domestic eggs, tropical fruit}:  sup = 0.011
# {domestic eggs, yogurt}:  sup = 0.014
# {domestic eggs, whole milk}:  sup = 0.03
# {domestic eggs, soda}:  sup = 0.012
# {domestic eggs, root vegetables}:  sup = 0.014
# {canned beer, rolls/buns}:  sup = 0.011
# {rolls/buns, shopping bags}:  sup = 0.02
# {sausage, shopping bags}:  sup = 0.016
# {whole milk, dessert}:  sup = 0.014
# {dessert, other vegetables}:  sup = 0.012
# {pastry, soda}:  sup = 0.021
# {whole milk, soda}:  sup = 0.04
# {other vegetables, soda}:  sup = 0.033
# {berries, whole milk}:  sup = 0.012
# {berries, other vegetables}:  sup = 0.01
# {whole milk, pork}:  sup = 0.022
# {pork, other vegetables}:  sup = 0.022
# {pork, soda}:  sup = 0.012
# {whole milk, whipped/sour cream}:  sup = 0.032
# {whipped/sour cream, other vegetables}:  sup = 0.029
# {whipped/sour cream, soda}:  sup = 0.012
# {whole milk, sugar}:  sup = 0.015
# {other vegetables, sugar}:  sup = 0.011
# {whole milk, root vegetables}:  sup = 0.049
# {bottled water, rolls/buns}:  sup = 0.024
# {hamburger meat, other vegetables}:  sup = 0.014
# {other vegetables, napkins}:  sup = 0.014
# {rolls/buns, napkins}:  sup = 0.012
# {fruit/vegetable juice, soda}:  sup = 0.018
# {newspapers, soda}:  sup = 0.015
# {canned beer, soda}:  sup = 0.014
# {brown bread, soda}:  sup = 0.013
# {soda, shopping bags}:  sup = 0.025
# {fruit/vegetable juice, shopping bags}:  sup = 0.011
# {canned beer, shopping bags}:  sup = 0.011
# {rolls/buns, chocolate}:  sup = 0.012
# {chocolate, soda}:  sup = 0.014
# {sausage, rolls/buns}:  sup = 0.031
# {sausage, soda}:  sup = 0.024
# {tropical fruit, rolls/buns}:  sup = 0.025
# {tropical fruit, root vegetables}:  sup = 0.021
# {other vegetables, root vegetables}:  sup = 0.047
# {rolls/buns, root vegetables}:  sup = 0.024
# {salty snack, other vegetables}:  sup = 0.011
# {other vegetables, waffles}:  sup = 0.01
# {tropical fruit, newspapers}:  sup = 0.012
# {frankfurter, rolls/buns}:  sup = 0.019
# {rolls/buns, soda}:  sup = 0.038
# {frankfurter, soda}:  sup = 0.011
# {citrus fruit, tropical fruit}:  sup = 0.02
# {citrus fruit, yogurt}:  sup = 0.022
# {citrus fruit, whole milk}:  sup = 0.031
# {whole milk, tropical fruit}:  sup = 0.042
# {citrus fruit, bottled water}:  sup = 0.014
# {bottled water, yogurt}:  sup = 0.023
# {whole milk, bottled water}:  sup = 0.034
# {tropical fruit, curd}:  sup = 0.01
# {yogurt, curd}:  sup = 0.017
# {whole milk, curd}:  sup = 0.026
# {tropical fruit, other vegetables}:  sup = 0.036
# {tropical fruit, bottled water}:  sup = 0.019
# {other vegetables, bottled water}:  sup = 0.025
# {other vegetables, chocolate}:  sup = 0.013
# {white bread, other vegetables}:  sup = 0.014
# {other vegetables, rolls/buns}:  sup = 0.043
# {bottled beer, other vegetables}:  sup = 0.016
# {bottled beer, rolls/buns}:  sup = 0.014
# {whole milk, yogurt}:  sup = 0.056
# {butter, yogurt}:  sup = 0.015
# {butter, whole milk}:  sup = 0.028
# {long life bakery product, whole milk}:  sup = 0.014
# {whole milk, other vegetables}:  sup = 0.075
# {long life bakery product, other vegetables}:  sup = 0.011
# {cream cheese , yogurt}:  sup = 0.012
# {pip fruit, yogurt}:  sup = 0.018
# {tropical fruit, yogurt}:  sup = 0.029
# {other vegetables, whole milk, pastry}:  sup = 0.011
# {rolls/buns, other vegetables, yogurt}:  sup = 0.011
# {other vegetables, whole milk, bottled water}:  sup = 0.011
# {whole milk, yogurt, rolls/buns}:  sup = 0.016
# {citrus fruit, whole milk, other vegetables}:  sup = 0.013
# {sausage, whole milk, other vegetables}:  sup = 0.01
# {butter, whole milk, other vegetables}:  sup = 0.011
# {tropical fruit, other vegetables, yogurt}:  sup = 0.012
# {whipped/sour cream, other vegetables, yogurt}:  sup = 0.01
# {whole milk, whipped/sour cream, yogurt}:  sup = 0.011
# {whole milk, tropical fruit, other vegetables}:  sup = 0.017
# {whole milk, other vegetables, fruit/vegetable juice}:  sup = 0.01
# {whole milk, other vegetables, yogurt}:  sup = 0.022
# {root vegetables, other vegetables, yogurt}:  sup = 0.013
# {whole milk, other vegetables, pip fruit}:  sup = 0.014
# {domestic eggs, whole milk, other vegetables}:  sup = 0.012
# {citrus fruit, other vegetables, root vegetables}:  sup = 0.01
# {whole milk, root vegetables, rolls/buns}:  sup = 0.013
# {whole milk, other vegetables, rolls/buns}:  sup = 0.018
# {whole milk, tropical fruit, rolls/buns}:  sup = 0.011
# {whole milk, tropical fruit, root vegetables}:  sup = 0.012
# {yogurt, whole milk, root vegetables}:  sup = 0.015
# {yogurt, whole milk, soda}:  sup = 0.01
# {whole milk, whipped/sour cream, other vegetables}:  sup = 0.015
# {whole milk, pork, other vegetables}:  sup = 0.01
# {whole milk, other vegetables, soda}:  sup = 0.014
# {whole milk, other vegetables, root vegetables}:  sup = 0.023
# {rolls/buns, other vegetables, root vegetables}:  sup = 0.012
# {tropical fruit, other vegetables, root vegetables}:  sup = 0.012
# {yogurt, whole milk, curd}:  sup = 0.01
# {whole milk, tropical fruit, yogurt}:  sup = 0.015
# {citrus fruit, whole milk, yogurt}:  sup = 0.01

# %%
#listing association rules derived
Association = generate_rules(Fi, Frequent_items, min_confidence=0.01, verbose=True)
# Out:
# {soda} ---> {margarine}:  conf = 0.058, sup = 0.01
# {margarine} ---> {soda}:  conf = 0.174, sup = 0.01
# {root vegetables} ---> {newspapers}:  conf = 0.105, sup = 0.011
# {newspapers} ---> {root vegetables}:  conf = 0.144, sup = 0.011
# {soda} ---> {white bread}:  conf = 0.059, sup = 0.01
# {white bread} ---> {soda}:  conf = 0.244, sup = 0.01
# {rolls/buns} ---> {coffee}:  conf = 0.06, sup = 0.011
# {coffee} ---> {rolls/buns}:  conf = 0.189, sup = 0.011
# {yogurt} ---> {beef}:  conf = 0.084, sup = 0.012
# {beef} ---> {yogurt}:  conf = 0.223, sup = 0.012
# {pip fruit} ---> {pastry}:  conf = 0.141, sup = 0.011
# {pastry} ---> {pip fruit}:  conf = 0.12, sup = 0.011
# {whole milk} ---> {chicken}:  conf = 0.069, sup = 0.018
# {chicken} ---> {whole milk}:  conf = 0.41, sup = 0.018
# {yogurt} ---> {margarine}:  conf = 0.102, sup = 0.014
# {margarine} ---> {yogurt}:  conf = 0.243, sup = 0.014
# {soda} ---> {pip fruit}:  conf = 0.076, sup = 0.013
# {pip fruit} ---> {soda}:  conf = 0.176, sup = 0.013
# {napkins} ---> {tropical fruit}:  conf = 0.192, sup = 0.01
# {tropical fruit} ---> {napkins}:  conf = 0.096, sup = 0.01
# {whole milk} ---> {onions}:  conf = 0.047, sup = 0.012
# {onions} ---> {whole milk}:  conf = 0.39, sup = 0.012
# {other vegetables} ---> {onions}:  conf = 0.074, sup = 0.014
# {onions} ---> {other vegetables}:  conf = 0.459, sup = 0.014
# {soda} ---> {citrus fruit}:  conf = 0.073, sup = 0.013
# {citrus fruit} ---> {soda}:  conf = 0.155, sup = 0.013
# {newspapers} ---> {other vegetables}:  conf = 0.242, sup = 0.019
# {other vegetables} ---> {newspapers}:  conf = 0.1, sup = 0.019
# {pip fruit} ---> {bottled water}:  conf = 0.14, sup = 0.011
# {bottled water} ---> {pip fruit}:  conf = 0.096, sup = 0.011
# {bottled water} ---> {sausage}:  conf = 0.109, sup = 0.012
# {sausage} ---> {bottled water}:  conf = 0.128, sup = 0.012
# {napkins} ---> {soda}:  conf = 0.229, sup = 0.012
# {soda} ---> {napkins}:  conf = 0.069, sup = 0.012
# {shopping bags} ---> {root vegetables}:  conf = 0.13, sup = 0.013
# {root vegetables} ---> {shopping bags}:  conf = 0.118, sup = 0.013
# {beef} ---> {other vegetables}:  conf = 0.376, sup = 0.02
# {other vegetables} ---> {beef}:  conf = 0.102, sup = 0.02
# {butter milk} ---> {other vegetables}:  conf = 0.371, sup = 0.01
# {other vegetables} ---> {butter milk}:  conf = 0.054, sup = 0.01
# {root vegetables} ---> {pork}:  conf = 0.125, sup = 0.014
# {pork} ---> {root vegetables}:  conf = 0.236, sup = 0.014
# {shopping bags} ---> {tropical fruit}:  conf = 0.137, sup = 0.014
# {tropical fruit} ---> {shopping bags}:  conf = 0.129, sup = 0.014
# {other vegetables} ---> {cream cheese}:  conf = 0.071, sup = 0.014
# {cream cheese} ---> {other vegetables}:  conf = 0.346, sup = 0.014
# {yogurt} ---> {frankfurter}:  conf = 0.08, sup = 0.011
# {frankfurter} ---> {yogurt}:  conf = 0.19, sup = 0.011
# {root vegetables} ---> {pip fruit}:  conf = 0.143, sup = 0.016
# {pip fruit} ---> {root vegetables}:  conf = 0.206, sup = 0.016
# {tropical fruit} ---> {whipped/sour cream}:  conf = 0.132, sup = 0.014
# {whipped/sour cream} ---> {tropical fruit}:  conf = 0.193, sup = 0.014
# {yogurt} ---> {whipped/sour cream}:  conf = 0.149, sup = 0.021
# {whipped/sour cream} ---> {yogurt}:  conf = 0.289, sup = 0.021
# {sliced cheese} ---> {whole milk}:  conf = 0.44, sup = 0.011
# {whole milk} ---> {sliced cheese}:  conf = 0.042, sup = 0.011
# {shopping bags} ---> {bottled water}:  conf = 0.111, sup = 0.011
# {bottled water} ---> {shopping bags}:  conf = 0.099, sup = 0.011
# {whole milk} ---> {white bread}:  conf = 0.067, sup = 0.017
# {white bread} ---> {whole milk}:  conf = 0.406, sup = 0.017
# {yogurt} ---> {frozen vegetables}:  conf = 0.089, sup = 0.012
# {frozen vegetables} ---> {yogurt}:  conf = 0.258, sup = 0.012
# {yogurt} ---> {other vegetables}:  conf = 0.311, sup = 0.043
# {other vegetables} ---> {yogurt}:  conf = 0.224, sup = 0.043
# {rolls/buns} ---> {citrus fruit}:  conf = 0.091, sup = 0.017
# {citrus fruit} ---> {rolls/buns}:  conf = 0.203, sup = 0.017
# {pip fruit} ---> {other vegetables}:  conf = 0.345, sup = 0.026
# {other vegetables} ---> {pip fruit}:  conf = 0.135, sup = 0.026
# {pip fruit} ---> {citrus fruit}:  conf = 0.183, sup = 0.014
# {citrus fruit} ---> {pip fruit}:  conf = 0.167, sup = 0.014
# {fruit/vegetable juice} ---> {citrus fruit}:  conf = 0.143, sup = 0.01
# {citrus fruit} ---> {fruit/vegetable juice}:  conf = 0.125, sup = 0.01
# {citrus fruit} ---> {sausage}:  conf = 0.136, sup = 0.011
# {sausage} ---> {citrus fruit}:  conf = 0.12, sup = 0.011
# {tropical fruit} ---> {sausage}:  conf = 0.133, sup = 0.014
# {sausage} ---> {tropical fruit}:  conf = 0.148, sup = 0.014
# {pip fruit} ---> {sausage}:  conf = 0.142, sup = 0.011
# {sausage} ---> {pip fruit}:  conf = 0.115, sup = 0.011
# {whole milk} ---> {hygiene articles}:  conf = 0.05, sup = 0.013
# {hygiene articles} ---> {whole milk}:  conf = 0.389, sup = 0.013
# {whole milk} ---> {hard cheese}:  conf = 0.039, sup = 0.01
# {hard cheese} ---> {whole milk}:  conf = 0.411, sup = 0.01
# {other vegetables} ---> {coffee}:  conf = 0.069, sup = 0.013
# {coffee} ---> {other vegetables}:  conf = 0.231, sup = 0.013
# {pastry} ---> {other vegetables}:  conf = 0.254, sup = 0.023
# {other vegetables} ---> {pastry}:  conf = 0.117, sup = 0.023
# {shopping bags} ---> {other vegetables}:  conf = 0.235, sup = 0.023
# {other vegetables} ---> {shopping bags}:  conf = 0.12, sup = 0.023
# {shopping bags} ---> {pastry}:  conf = 0.121, sup = 0.012
# {pastry} ---> {shopping bags}:  conf = 0.134, sup = 0.012
# {whole milk} ---> {cream cheese}:  conf = 0.064, sup = 0.016
# {cream cheese} ---> {whole milk}:  conf = 0.415, sup = 0.016
# {hamburger meat} ---> {whole milk}:  conf = 0.443, sup = 0.015
# {whole milk} ---> {hamburger meat}:  conf = 0.058, sup = 0.015
# {bottled water} ---> {margarine}:  conf = 0.093, sup = 0.01
# {margarine} ---> {bottled water}:  conf = 0.175, sup = 0.01
# {other vegetables} ---> {frankfurter}:  conf = 0.085, sup = 0.016
# {frankfurter} ---> {other vegetables}:  conf = 0.279, sup = 0.016
# {root vegetables} ---> {frankfurter}:  conf = 0.093, sup = 0.01
# {frankfurter} ---> {root vegetables}:  conf = 0.172, sup = 0.01
# {other vegetables} ---> {sausage}:  conf = 0.139, sup = 0.027
# {sausage} ---> {other vegetables}:  conf = 0.287, sup = 0.027
# {frankfurter} ---> {sausage}:  conf = 0.171, sup = 0.01
# {sausage} ---> {frankfurter}:  conf = 0.107, sup = 0.01
# {root vegetables} ---> {beef}:  conf = 0.16, sup = 0.017
# {beef} ---> {root vegetables}:  conf = 0.331, sup = 0.017
# {whole milk} ---> {bottled beer}:  conf = 0.08, sup = 0.02
# {bottled beer} ---> {whole milk}:  conf = 0.254, sup = 0.02
# {yogurt} ---> {fruit/vegetable juice}:  conf = 0.134, sup = 0.019
# {fruit/vegetable juice} ---> {yogurt}:  conf = 0.259, sup = 0.019
# {shopping bags} ---> {yogurt}:  conf = 0.155, sup = 0.015
# {yogurt} ---> {shopping bags}:  conf = 0.109, sup = 0.015
# {shopping bags} ---> {whole milk}:  conf = 0.249, sup = 0.025
# {whole milk} ---> {shopping bags}:  conf = 0.096, sup = 0.025
# {napkins} ---> {yogurt}:  conf = 0.235, sup = 0.012
# {yogurt} ---> {napkins}:  conf = 0.088, sup = 0.012
# {napkins} ---> {whole milk}:  conf = 0.377, sup = 0.02
# {whole milk} ---> {napkins}:  conf = 0.077, sup = 0.02
# {rolls/buns} ---> {pork}:  conf = 0.061, sup = 0.011
# {pork} ---> {rolls/buns}:  conf = 0.196, sup = 0.011
# {other vegetables} ---> {citrus fruit}:  conf = 0.149, sup = 0.029
# {citrus fruit} ---> {other vegetables}:  conf = 0.349, sup = 0.029
# {other vegetables} ---> {chicken}:  conf = 0.092, sup = 0.018
# {chicken} ---> {other vegetables}:  conf = 0.417, sup = 0.018
# {root vegetables} ---> {citrus fruit}:  conf = 0.162, sup = 0.018
# {citrus fruit} ---> {root vegetables}:  conf = 0.214, sup = 0.018
# {root vegetables} ---> {chicken}:  conf = 0.1, sup = 0.011
# {chicken} ---> {root vegetables}:  conf = 0.254, sup = 0.011
# {fruit/vegetable juice} ---> {sausage}:  conf = 0.139, sup = 0.01
# {sausage} ---> {fruit/vegetable juice}:  conf = 0.107, sup = 0.01
# {sausage} ---> {brown bread}:  conf = 0.114, sup = 0.011
# {brown bread} ---> {sausage}:  conf = 0.165, sup = 0.011
# {whipped/sour cream} ---> {citrus fruit}:  conf = 0.152, sup = 0.011
# {citrus fruit} ---> {whipped/sour cream}:  conf = 0.131, sup = 0.011
# {yogurt} ---> {sausage}:  conf = 0.141, sup = 0.02
# {sausage} ---> {yogurt}:  conf = 0.209, sup = 0.02
# {root vegetables} ---> {sausage}:  conf = 0.137, sup = 0.015
# {sausage} ---> {root vegetables}:  conf = 0.159, sup = 0.015
# {rolls/buns} ---> {margarine}:  conf = 0.08, sup = 0.015
# {margarine} ---> {rolls/buns}:  conf = 0.252, sup = 0.015
# {fruit/vegetable juice} ---> {whole milk}:  conf = 0.368, sup = 0.027
# {whole milk} ---> {fruit/vegetable juice}:  conf = 0.104, sup = 0.027
# {rolls/buns} ---> {fruit/vegetable juice}:  conf = 0.079, sup = 0.015
# {fruit/vegetable juice} ---> {rolls/buns}:  conf = 0.201, sup = 0.015
# {root vegetables} ---> {margarine}:  conf = 0.102, sup = 0.011
# {margarine} ---> {root vegetables}:  conf = 0.189, sup = 0.011
# {root vegetables} ---> {fruit/vegetable juice}:  conf = 0.11, sup = 0.012
# {fruit/vegetable juice} ---> {root vegetables}:  conf = 0.166, sup = 0.012
# {rolls/buns} ---> {domestic eggs}:  conf = 0.085, sup = 0.016
# {domestic eggs} ---> {rolls/buns}:  conf = 0.247, sup = 0.016
# {rolls/buns} ---> {frozen vegetables}:  conf = 0.055, sup = 0.01
# {frozen vegetables} ---> {rolls/buns}:  conf = 0.211, sup = 0.01
# {root vegetables} ---> {frozen vegetables}:  conf = 0.106, sup = 0.012
# {frozen vegetables} ---> {root vegetables}:  conf = 0.241, sup = 0.012
# {soda} ---> {bottled beer}:  conf = 0.097, sup = 0.017
# {bottled beer} ---> {soda}:  conf = 0.211, sup = 0.017
# {bottled water} ---> {bottled beer}:  conf = 0.143, sup = 0.016
# {bottled beer} ---> {bottled water}:  conf = 0.196, sup = 0.016
# {fruit/vegetable juice} ---> {bottled water}:  conf = 0.197, sup = 0.014
# {bottled water} ---> {fruit/vegetable juice}:  conf = 0.129, sup = 0.014
# {butter milk} ---> {whole milk}:  conf = 0.415, sup = 0.012
# {whole milk} ---> {butter milk}:  conf = 0.045, sup = 0.012
# {whole milk} ---> {frankfurter}:  conf = 0.08, sup = 0.021
# {frankfurter} ---> {whole milk}:  conf = 0.348, sup = 0.021
# {newspapers} ---> {whole milk}:  conf = 0.343, sup = 0.027
# {whole milk} ---> {newspapers}:  conf = 0.107, sup = 0.027
# {domestic eggs} ---> {citrus fruit}:  conf = 0.163, sup = 0.01
# {citrus fruit} ---> {domestic eggs}:  conf = 0.125, sup = 0.01
# {whole milk} ---> {oil}:  conf = 0.044, sup = 0.011
# {oil} ---> {whole milk}:  conf = 0.402, sup = 0.011
# {whole milk} ---> {margarine}:  conf = 0.095, sup = 0.024
# {margarine} ---> {whole milk}:  conf = 0.413, sup = 0.024
# {pip fruit} ---> {tropical fruit}:  conf = 0.27, sup = 0.02
# {tropical fruit} ---> {pip fruit}:  conf = 0.195, sup = 0.02
# {pip fruit} ---> {whole milk}:  conf = 0.398, sup = 0.03
# {whole milk} ---> {pip fruit}:  conf = 0.118, sup = 0.03
# {rolls/buns} ---> {whole milk}:  conf = 0.308, sup = 0.057
# {whole milk} ---> {rolls/buns}:  conf = 0.222, sup = 0.057
# {rolls/buns} ---> {pip fruit}:  conf = 0.076, sup = 0.014
# {pip fruit} ---> {rolls/buns}:  conf = 0.184, sup = 0.014
# {chocolate} ---> {whole milk}:  conf = 0.336, sup = 0.017
# {whole milk} ---> {chocolate}:  conf = 0.065, sup = 0.017
# {rolls/buns} ---> {brown bread}:  conf = 0.069, sup = 0.013
# {brown bread} ---> {rolls/buns}:  conf = 0.194, sup = 0.013
# {beef} ---> {whole milk}:  conf = 0.405, sup = 0.021
# {whole milk} ---> {beef}:  conf = 0.083, sup = 0.021
# {whole milk} ---> {sausage}:  conf = 0.117, sup = 0.03
# {sausage} ---> {whole milk}:  conf = 0.318, sup = 0.03
# {pastry} ---> {sausage}:  conf = 0.141, sup = 0.013
# {sausage} ---> {pastry}:  conf = 0.133, sup = 0.013
# {whole milk} ---> {salty snack}:  conf = 0.044, sup = 0.011
# {salty snack} ---> {whole milk}:  conf = 0.296, sup = 0.011
# {whole milk} ---> {frozen vegetables}:  conf = 0.08, sup = 0.02
# {frozen vegetables} ---> {whole milk}:  conf = 0.425, sup = 0.02
# {other vegetables} ---> {frozen vegetables}:  conf = 0.092, sup = 0.018
# {frozen vegetables} ---> {other vegetables}:  conf = 0.37, sup = 0.018
# {rolls/buns} ---> {pastry}:  conf = 0.114, sup = 0.021
# {pastry} ---> {rolls/buns}:  conf = 0.235, sup = 0.021
# {rolls/buns} ---> {beef}:  conf = 0.074, sup = 0.014
# {beef} ---> {rolls/buns}:  conf = 0.26, sup = 0.014
# {other vegetables} ---> {margarine}:  conf = 0.102, sup = 0.02
# {margarine} ---> {other vegetables}:  conf = 0.337, sup = 0.02
# {fruit/vegetable juice} ---> {tropical fruit}:  conf = 0.19, sup = 0.014
# {tropical fruit} ---> {fruit/vegetable juice}:  conf = 0.131, sup = 0.014
# {fruit/vegetable juice} ---> {other vegetables}:  conf = 0.291, sup = 0.021
# {other vegetables} ---> {fruit/vegetable juice}:  conf = 0.109, sup = 0.021
# {other vegetables} ---> {brown bread}:  conf = 0.097, sup = 0.019
# {brown bread} ---> {other vegetables}:  conf = 0.288, sup = 0.019
# {other vegetables} ---> {domestic eggs}:  conf = 0.115, sup = 0.022
# {domestic eggs} ---> {other vegetables}:  conf = 0.351, sup = 0.022
# {whole milk} ---> {ham}:  conf = 0.045, sup = 0.011
# {ham} ---> {whole milk}:  conf = 0.441, sup = 0.011
# {other vegetables} ---> {butter}:  conf = 0.104, sup = 0.02
# {butter} ---> {other vegetables}:  conf = 0.361, sup = 0.02
# {rolls/buns} ---> {butter}:  conf = 0.073, sup = 0.013
# {butter} ---> {rolls/buns}:  conf = 0.242, sup = 0.013
# {curd} ---> {other vegetables}:  conf = 0.323, sup = 0.017
# {other vegetables} ---> {curd}:  conf = 0.089, sup = 0.017
# {curd} ---> {rolls/buns}:  conf = 0.189, sup = 0.01
# {rolls/buns} ---> {curd}:  conf = 0.055, sup = 0.01
# {root vegetables} ---> {butter}:  conf = 0.118, sup = 0.013
# {butter} ---> {root vegetables}:  conf = 0.233, sup = 0.013
# {root vegetables} ---> {bottled water}:  conf = 0.144, sup = 0.016
# {bottled water} ---> {root vegetables}:  conf = 0.142, sup = 0.016
# {root vegetables} ---> {curd}:  conf = 0.1, sup = 0.011
# {curd} ---> {root vegetables}:  conf = 0.204, sup = 0.011
# {whipped/sour cream} ---> {butter}:  conf = 0.142, sup = 0.01
# {butter} ---> {whipped/sour cream}:  conf = 0.183, sup = 0.01
# {rolls/buns} ---> {whipped/sour cream}:  conf = 0.08, sup = 0.015
# {whipped/sour cream} ---> {rolls/buns}:  conf = 0.204, sup = 0.015
# {curd} ---> {whipped/sour cream}:  conf = 0.197, sup = 0.01
# {whipped/sour cream} ---> {curd}:  conf = 0.146, sup = 0.01
# {root vegetables} ---> {whipped/sour cream}:  conf = 0.157, sup = 0.017
# {whipped/sour cream} ---> {root vegetables}:  conf = 0.238, sup = 0.017
# {rolls/buns} ---> {yogurt}:  conf = 0.187, sup = 0.034
# {yogurt} ---> {rolls/buns}:  conf = 0.246, sup = 0.034
# {soda} ---> {bottled water}:  conf = 0.166, sup = 0.029
# {bottled water} ---> {soda}:  conf = 0.262, sup = 0.029
# {yogurt} ---> {newspapers}:  conf = 0.11, sup = 0.015
# {newspapers} ---> {yogurt}:  conf = 0.192, sup = 0.015
# {rolls/buns} ---> {newspapers}:  conf = 0.107, sup = 0.02
# {newspapers} ---> {rolls/buns}:  conf = 0.247, sup = 0.02
# {newspapers} ---> {bottled water}:  conf = 0.141, sup = 0.011
# {bottled water} ---> {newspapers}:  conf = 0.102, sup = 0.011
# {yogurt} ---> {berries}:  conf = 0.076, sup = 0.011
# {berries} ---> {yogurt}:  conf = 0.318, sup = 0.011
# {coffee} ---> {whole milk}:  conf = 0.322, sup = 0.019
# {whole milk} ---> {coffee}:  conf = 0.073, sup = 0.019
# {soda} ---> {tropical fruit}:  conf = 0.12, sup = 0.021
# {tropical fruit} ---> {soda}:  conf = 0.199, sup = 0.021
# {soda} ---> {yogurt}:  conf = 0.157, sup = 0.027
# {yogurt} ---> {soda}:  conf = 0.196, sup = 0.027
# {pastry} ---> {tropical fruit}:  conf = 0.149, sup = 0.013
# {tropical fruit} ---> {pastry}:  conf = 0.126, sup = 0.013
# {yogurt} ---> {pastry}:  conf = 0.127, sup = 0.018
# {pastry} ---> {yogurt}:  conf = 0.199, sup = 0.018
# {pastry} ---> {whole milk}:  conf = 0.374, sup = 0.033
# {whole milk} ---> {pastry}:  conf = 0.13, sup = 0.033
# {root vegetables} ---> {yogurt}:  conf = 0.237, sup = 0.026
# {yogurt} ---> {root vegetables}:  conf = 0.185, sup = 0.026
# {root vegetables} ---> {soda}:  conf = 0.171, sup = 0.019
# {soda} ---> {root vegetables}:  conf = 0.107, sup = 0.019
# {root vegetables} ---> {pastry}:  conf = 0.101, sup = 0.011
# {pastry} ---> {root vegetables}:  conf = 0.123, sup = 0.011
# {waffles} ---> {whole milk}:  conf = 0.331, sup = 0.013
# {whole milk} ---> {waffles}:  conf = 0.05, sup = 0.013
# {tropical fruit} ---> {brown bread}:  conf = 0.102, sup = 0.011
# {brown bread} ---> {tropical fruit}:  conf = 0.165, sup = 0.011
# {yogurt} ---> {brown bread}:  conf = 0.104, sup = 0.015
# {brown bread} ---> {yogurt}:  conf = 0.224, sup = 0.015
# {whole milk} ---> {brown bread}:  conf = 0.099, sup = 0.025
# {brown bread} ---> {whole milk}:  conf = 0.389, sup = 0.025
# {root vegetables} ---> {brown bread}:  conf = 0.093, sup = 0.01
# {brown bread} ---> {root vegetables}:  conf = 0.157, sup = 0.01
# {tropical fruit} ---> {domestic eggs}:  conf = 0.109, sup = 0.011
# {domestic eggs} ---> {tropical fruit}:  conf = 0.179, sup = 0.011
# {yogurt} ---> {domestic eggs}:  conf = 0.103, sup = 0.014
# {domestic eggs} ---> {yogurt}:  conf = 0.226, sup = 0.014
# {whole milk} ---> {domestic eggs}:  conf = 0.117, sup = 0.03
# {domestic eggs} ---> {whole milk}:  conf = 0.473, sup = 0.03
# {soda} ---> {domestic eggs}:  conf = 0.071, sup = 0.012
# {domestic eggs} ---> {soda}:  conf = 0.196, sup = 0.012
# {root vegetables} ---> {domestic eggs}:  conf = 0.132, sup = 0.014
# {domestic eggs} ---> {root vegetables}:  conf = 0.226, sup = 0.014
# {rolls/buns} ---> {canned beer}:  conf = 0.061, sup = 0.011
# {canned beer} ---> {rolls/buns}:  conf = 0.145, sup = 0.011
# {shopping bags} ---> {rolls/buns}:  conf = 0.198, sup = 0.02
# {rolls/buns} ---> {shopping bags}:  conf = 0.106, sup = 0.02
# {shopping bags} ---> {sausage}:  conf = 0.159, sup = 0.016
# {sausage} ---> {shopping bags}:  conf = 0.167, sup = 0.016
# {dessert} ---> {whole milk}:  conf = 0.37, sup = 0.014
# {whole milk} ---> {dessert}:  conf = 0.054, sup = 0.014
# {other vegetables} ---> {dessert}:  conf = 0.06, sup = 0.012
# {dessert} ---> {other vegetables}:  conf = 0.312, sup = 0.012
# {soda} ---> {pastry}:  conf = 0.121, sup = 0.021
# {pastry} ---> {soda}:  conf = 0.237, sup = 0.021
# {soda} ---> {whole milk}:  conf = 0.23, sup = 0.04
# {whole milk} ---> {soda}:  conf = 0.157, sup = 0.04
# {soda} ---> {other vegetables}:  conf = 0.188, sup = 0.033
# {other vegetables} ---> {soda}:  conf = 0.169, sup = 0.033
# {whole milk} ---> {berries}:  conf = 0.046, sup = 0.012
# {berries} ---> {whole milk}:  conf = 0.355, sup = 0.012
# {other vegetables} ---> {berries}:  conf = 0.053, sup = 0.01
# {berries} ---> {other vegetables}:  conf = 0.309, sup = 0.01
# {pork} ---> {whole milk}:  conf = 0.384, sup = 0.022
# {whole milk} ---> {pork}:  conf = 0.087, sup = 0.022
# {other vegetables} ---> {pork}:  conf = 0.112, sup = 0.022
# {pork} ---> {other vegetables}:  conf = 0.376, sup = 0.022
# {soda} ---> {pork}:  conf = 0.068, sup = 0.012
# {pork} ---> {soda}:  conf = 0.206, sup = 0.012
# {whipped/sour cream} ---> {whole milk}:  conf = 0.45, sup = 0.032
# {whole milk} ---> {whipped/sour cream}:  conf = 0.126, sup = 0.032
# {other vegetables} ---> {whipped/sour cream}:  conf = 0.149, sup = 0.029
# {whipped/sour cream} ---> {other vegetables}:  conf = 0.403, sup = 0.029
# {soda} ---> {whipped/sour cream}:  conf = 0.066, sup = 0.012
# {whipped/sour cream} ---> {soda}:  conf = 0.162, sup = 0.012
# {sugar} ---> {whole milk}:  conf = 0.444, sup = 0.015
# {whole milk} ---> {sugar}:  conf = 0.059, sup = 0.015
# {sugar} ---> {other vegetables}:  conf = 0.318, sup = 0.011
# {other vegetables} ---> {sugar}:  conf = 0.056, sup = 0.011
# {root vegetables} ---> {whole milk}:  conf = 0.449, sup = 0.049
# {whole milk} ---> {root vegetables}:  conf = 0.191, sup = 0.049
# {rolls/buns} ---> {bottled water}:  conf = 0.132, sup = 0.024
# {bottled water} ---> {rolls/buns}:  conf = 0.219, sup = 0.024
# {other vegetables} ---> {hamburger meat}:  conf = 0.071, sup = 0.014
# {hamburger meat} ---> {other vegetables}:  conf = 0.416, sup = 0.014
# {napkins} ---> {other vegetables}:  conf = 0.276, sup = 0.014
# {other vegetables} ---> {napkins}:  conf = 0.075, sup = 0.014
# {napkins} ---> {rolls/buns}:  conf = 0.223, sup = 0.012
# {rolls/buns} ---> {napkins}:  conf = 0.064, sup = 0.012
# {soda} ---> {fruit/vegetable juice}:  conf = 0.106, sup = 0.018
# {fruit/vegetable juice} ---> {soda}:  conf = 0.255, sup = 0.018
# {soda} ---> {newspapers}:  conf = 0.084, sup = 0.015
# {newspapers} ---> {soda}:  conf = 0.183, sup = 0.015
# {soda} ---> {canned beer}:  conf = 0.079, sup = 0.014
# {canned beer} ---> {soda}:  conf = 0.178, sup = 0.014
# {soda} ---> {brown bread}:  conf = 0.072, sup = 0.013
# {brown bread} ---> {soda}:  conf = 0.194, sup = 0.013
# {shopping bags} ---> {soda}:  conf = 0.25, sup = 0.025
# {soda} ---> {shopping bags}:  conf = 0.141, sup = 0.025
# {shopping bags} ---> {fruit/vegetable juice}:  conf = 0.108, sup = 0.011
# {fruit/vegetable juice} ---> {shopping bags}:  conf = 0.148, sup = 0.011
# {shopping bags} ---> {canned beer}:  conf = 0.116, sup = 0.011
# {canned beer} ---> {shopping bags}:  conf = 0.147, sup = 0.011
# {chocolate} ---> {rolls/buns}:  conf = 0.238, sup = 0.012
# {rolls/buns} ---> {chocolate}:  conf = 0.064, sup = 0.012
# {soda} ---> {chocolate}:  conf = 0.078, sup = 0.014
# {chocolate} ---> {soda}:  conf = 0.273, sup = 0.014
# {rolls/buns} ---> {sausage}:  conf = 0.166, sup = 0.031
# {sausage} ---> {rolls/buns}:  conf = 0.326, sup = 0.031
# {soda} ---> {sausage}:  conf = 0.139, sup = 0.024
# {sausage} ---> {soda}:  conf = 0.259, sup = 0.024
# {rolls/buns} ---> {tropical fruit}:  conf = 0.134, sup = 0.025
# {tropical fruit} ---> {rolls/buns}:  conf = 0.234, sup = 0.025
# {root vegetables} ---> {tropical fruit}:  conf = 0.193, sup = 0.021
# {tropical fruit} ---> {root vegetables}:  conf = 0.201, sup = 0.021
# {root vegetables} ---> {other vegetables}:  conf = 0.435, sup = 0.047
# {other vegetables} ---> {root vegetables}:  conf = 0.245, sup = 0.047
# {root vegetables} ---> {rolls/buns}:  conf = 0.223, sup = 0.024
# {rolls/buns} ---> {root vegetables}:  conf = 0.132, sup = 0.024
# {other vegetables} ---> {salty snack}:  conf = 0.056, sup = 0.011
# {salty snack} ---> {other vegetables}:  conf = 0.285, sup = 0.011
# {waffles} ---> {other vegetables}:  conf = 0.262, sup = 0.01
# {other vegetables} ---> {waffles}:  conf = 0.052, sup = 0.01
# {newspapers} ---> {tropical fruit}:  conf = 0.148, sup = 0.012
# {tropical fruit} ---> {newspapers}:  conf = 0.112, sup = 0.012
# {rolls/buns} ---> {frankfurter}:  conf = 0.104, sup = 0.019
# {frankfurter} ---> {rolls/buns}:  conf = 0.326, sup = 0.019
# {soda} ---> {rolls/buns}:  conf = 0.22, sup = 0.038
# {rolls/buns} ---> {soda}:  conf = 0.208, sup = 0.038
# {soda} ---> {frankfurter}:  conf = 0.065, sup = 0.011
# {frankfurter} ---> {soda}:  conf = 0.191, sup = 0.011
# {tropical fruit} ---> {citrus fruit}:  conf = 0.19, sup = 0.02
# {citrus fruit} ---> {tropical fruit}:  conf = 0.241, sup = 0.02
# {yogurt} ---> {citrus fruit}:  conf = 0.155, sup = 0.022
# {citrus fruit} ---> {yogurt}:  conf = 0.262, sup = 0.022
# {whole milk} ---> {citrus fruit}:  conf = 0.119, sup = 0.031
# {citrus fruit} ---> {whole milk}:  conf = 0.369, sup = 0.031
# {tropical fruit} ---> {whole milk}:  conf = 0.403, sup = 0.042
# {whole milk} ---> {tropical fruit}:  conf = 0.166, sup = 0.042
# {bottled water} ---> {citrus fruit}:  conf = 0.122, sup = 0.014
# {citrus fruit} ---> {bottled water}:  conf = 0.163, sup = 0.014
# {yogurt} ---> {bottled water}:  conf = 0.165, sup = 0.023
# {bottled water} ---> {yogurt}:  conf = 0.208, sup = 0.023
# {bottled water} ---> {whole milk}:  conf = 0.311, sup = 0.034
# {whole milk} ---> {bottled water}:  conf = 0.135, sup = 0.034
# {curd} ---> {tropical fruit}:  conf = 0.193, sup = 0.01
# {tropical fruit} ---> {curd}:  conf = 0.098, sup = 0.01
# {curd} ---> {yogurt}:  conf = 0.324, sup = 0.017
# {yogurt} ---> {curd}:  conf = 0.124, sup = 0.017
# {curd} ---> {whole milk}:  conf = 0.49, sup = 0.026
# {whole milk} ---> {curd}:  conf = 0.102, sup = 0.026
# {other vegetables} ---> {tropical fruit}:  conf = 0.185, sup = 0.036
# {tropical fruit} ---> {other vegetables}:  conf = 0.342, sup = 0.036
# {bottled water} ---> {tropical fruit}:  conf = 0.167, sup = 0.019
# {tropical fruit} ---> {bottled water}:  conf = 0.176, sup = 0.019
# {bottled water} ---> {other vegetables}:  conf = 0.224, sup = 0.025
# {other vegetables} ---> {bottled water}:  conf = 0.128, sup = 0.025
# {chocolate} ---> {other vegetables}:  conf = 0.256, sup = 0.013
# {other vegetables} ---> {chocolate}:  conf = 0.066, sup = 0.013
# {other vegetables} ---> {white bread}:  conf = 0.071, sup = 0.014
# {white bread} ---> {other vegetables}:  conf = 0.326, sup = 0.014
# {rolls/buns} ---> {other vegetables}:  conf = 0.232, sup = 0.043
# {other vegetables} ---> {rolls/buns}:  conf = 0.22, sup = 0.043
# {other vegetables} ---> {bottled beer}:  conf = 0.084, sup = 0.016
# {bottled beer} ---> {other vegetables}:  conf = 0.201, sup = 0.016
# {rolls/buns} ---> {bottled beer}:  conf = 0.074, sup = 0.014
# {bottled beer} ---> {rolls/buns}:  conf = 0.169, sup = 0.014
# {yogurt} ---> {whole milk}:  conf = 0.402, sup = 0.056
# {whole milk} ---> {yogurt}:  conf = 0.219, sup = 0.056
# {yogurt} ---> {butter}:  conf = 0.105, sup = 0.015
# {butter} ---> {yogurt}:  conf = 0.264, sup = 0.015
# {whole milk} ---> {butter}:  conf = 0.108, sup = 0.028
# {butter} ---> {whole milk}:  conf = 0.497, sup = 0.028
# {whole milk} ---> {long life bakery product}:  conf = 0.053, sup = 0.014
# {long life bakery product} ---> {whole milk}:  conf = 0.361, sup = 0.014
# {other vegetables} ---> {whole milk}:  conf = 0.387, sup = 0.075
# {whole milk} ---> {other vegetables}:  conf = 0.293, sup = 0.075
# {other vegetables} ---> {long life bakery product}:  conf = 0.055, sup = 0.011
# {long life bakery product} ---> {other vegetables}:  conf = 0.285, sup = 0.011
# {yogurt} ---> {cream cheese}:  conf = 0.089, sup = 0.012
# {cream cheese} ---> {yogurt}:  conf = 0.313, sup = 0.012
# {yogurt} ---> {pip fruit}:  conf = 0.129, sup = 0.018
# {pip fruit} ---> {yogurt}:  conf = 0.238, sup = 0.018
# {yogurt} ---> {tropical fruit}:  conf = 0.21, sup = 0.029
# {tropical fruit} ---> {yogurt}:  conf = 0.279, sup = 0.029
# {whole milk, pastry} ---> {other vegetables}:  conf = 0.318, sup = 0.011
# {pastry, other vegetables} ---> {whole milk}:  conf = 0.468, sup = 0.011
# {whole milk, other vegetables} ---> {pastry}:  conf = 0.141, sup = 0.011
# {pastry} ---> {whole milk, other vegetables}:  conf = 0.119, sup = 0.011
# {whole milk} ---> {pastry, other vegetables}:  conf = 0.041, sup = 0.011
# {other vegetables} ---> {whole milk, pastry}:  conf = 0.055, sup = 0.011
# {other vegetables, yogurt} ---> {rolls/buns}:  conf = 0.265, sup = 0.011
# {yogurt, rolls/buns} ---> {other vegetables}:  conf = 0.334, sup = 0.011
# {other vegetables, rolls/buns} ---> {yogurt}:  conf = 0.27, sup = 0.011
# {yogurt} ---> {other vegetables, rolls/buns}:  conf = 0.082, sup = 0.011
# {other vegetables} ---> {yogurt, rolls/buns}:  conf = 0.059, sup = 0.011
# {rolls/buns} ---> {other vegetables, yogurt}:  conf = 0.062, sup = 0.011
# {whole milk, bottled water} ---> {other vegetables}:  conf = 0.314, sup = 0.011
# {bottled water, other vegetables} ---> {whole milk}:  conf = 0.434, sup = 0.011
# {whole milk, other vegetables} ---> {bottled water}:  conf = 0.144, sup = 0.011
# {bottled water} ---> {whole milk, other vegetables}:  conf = 0.098, sup = 0.011
# {whole milk} ---> {bottled water, other vegetables}:  conf = 0.042, sup = 0.011
# {other vegetables} ---> {whole milk, bottled water}:  conf = 0.056, sup = 0.011
# {rolls/buns, yogurt} ---> {whole milk}:  conf = 0.453, sup = 0.016
# {whole milk, rolls/buns} ---> {yogurt}:  conf = 0.275, sup = 0.016
# {whole milk, yogurt} ---> {rolls/buns}:  conf = 0.278, sup = 0.016
# {rolls/buns} ---> {whole milk, yogurt}:  conf = 0.085, sup = 0.016
# {yogurt} ---> {whole milk, rolls/buns}:  conf = 0.112, sup = 0.016
# {whole milk} ---> {rolls/buns, yogurt}:  conf = 0.061, sup = 0.016
# {whole milk, other vegetables} ---> {citrus fruit}:  conf = 0.174, sup = 0.013
# {citrus fruit, other vegetables} ---> {whole milk}:  conf = 0.451, sup = 0.013
# {citrus fruit, whole milk} ---> {other vegetables}:  conf = 0.427, sup = 0.013
# {other vegetables} ---> {citrus fruit, whole milk}:  conf = 0.067, sup = 0.013
# {whole milk} ---> {citrus fruit, other vegetables}:  conf = 0.051, sup = 0.013
# {citrus fruit} ---> {whole milk, other vegetables}:  conf = 0.157, sup = 0.013
# {whole milk, other vegetables} ---> {sausage}:  conf = 0.136, sup = 0.01
# {sausage, other vegetables} ---> {whole milk}:  conf = 0.377, sup = 0.01
# {sausage, whole milk} ---> {other vegetables}:  conf = 0.34, sup = 0.01
# {other vegetables} ---> {sausage, whole milk}:  conf = 0.053, sup = 0.01
# {whole milk} ---> {sausage, other vegetables}:  conf = 0.04, sup = 0.01
# {sausage} ---> {whole milk, other vegetables}:  conf = 0.108, sup = 0.01
# {whole milk, other vegetables} ---> {butter}:  conf = 0.154, sup = 0.011
# {butter, other vegetables} ---> {whole milk}:  conf = 0.574, sup = 0.011
# {butter, whole milk} ---> {other vegetables}:  conf = 0.417, sup = 0.011
# {other vegetables} ---> {butter, whole milk}:  conf = 0.059, sup = 0.011
# {whole milk} ---> {butter, other vegetables}:  conf = 0.045, sup = 0.011
# {butter} ---> {whole milk, other vegetables}:  conf = 0.207, sup = 0.011
# {other vegetables, yogurt} ---> {tropical fruit}:  conf = 0.283, sup = 0.012
# {tropical fruit, yogurt} ---> {other vegetables}:  conf = 0.42, sup = 0.012
# {other vegetables, tropical fruit} ---> {yogurt}:  conf = 0.343, sup = 0.012
# {yogurt} ---> {other vegetables, tropical fruit}:  conf = 0.088, sup = 0.012
# {other vegetables} ---> {tropical fruit, yogurt}:  conf = 0.064, sup = 0.012
# {tropical fruit} ---> {other vegetables, yogurt}:  conf = 0.117, sup = 0.012
# {other vegetables, yogurt} ---> {whipped/sour cream}:  conf = 0.234, sup = 0.01
# {whipped/sour cream, yogurt} ---> {other vegetables}:  conf = 0.49, sup = 0.01
# {whipped/sour cream, other vegetables} ---> {yogurt}:  conf = 0.352, sup = 0.01
# {yogurt} ---> {whipped/sour cream, other vegetables}:  conf = 0.073, sup = 0.01
# {other vegetables} ---> {whipped/sour cream, yogurt}:  conf = 0.053, sup = 0.01
# {whipped/sour cream} ---> {other vegetables, yogurt}:  conf = 0.142, sup = 0.01
# {whipped/sour cream, yogurt} ---> {whole milk}:  conf = 0.525, sup = 0.011
# {whole milk, yogurt} ---> {whipped/sour cream}:  conf = 0.194, sup = 0.011
# {whole milk, whipped/sour cream} ---> {yogurt}:  conf = 0.338, sup = 0.011
# {yogurt} ---> {whole milk, whipped/sour cream}:  conf = 0.078, sup = 0.011
# {whipped/sour cream} ---> {whole milk, yogurt}:  conf = 0.152, sup = 0.011
# {whole milk} ---> {whipped/sour cream, yogurt}:  conf = 0.043, sup = 0.011
# {other vegetables, tropical fruit} ---> {whole milk}:  conf = 0.476, sup = 0.017
# {whole milk, other vegetables} ---> {tropical fruit}:  conf = 0.228, sup = 0.017
# {whole milk, tropical fruit} ---> {other vegetables}:  conf = 0.404, sup = 0.017
# {other vegetables} ---> {whole milk, tropical fruit}:  conf = 0.088, sup = 0.017
# {tropical fruit} ---> {whole milk, other vegetables}:  conf = 0.163, sup = 0.017
# {whole milk} ---> {other vegetables, tropical fruit}:  conf = 0.067, sup = 0.017
# {other vegetables, fruit/vegetable juice} ---> {whole milk}:  conf = 0.498, sup = 0.01
# {whole milk, fruit/vegetable juice} ---> {other vegetables}:  conf = 0.393, sup = 0.01
# {whole milk, other vegetables} ---> {fruit/vegetable juice}:  conf = 0.14, sup = 0.01
# {fruit/vegetable juice} ---> {whole milk, other vegetables}:  conf = 0.145, sup = 0.01
# {other vegetables} ---> {whole milk, fruit/vegetable juice}:  conf = 0.054, sup = 0.01
# {whole milk} ---> {other vegetables, fruit/vegetable juice}:  conf = 0.041, sup = 0.01
# {other vegetables, yogurt} ---> {whole milk}:  conf = 0.513, sup = 0.022
# {whole milk, yogurt} ---> {other vegetables}:  conf = 0.397, sup = 0.022
# {whole milk, other vegetables} ---> {yogurt}:  conf = 0.298, sup = 0.022
# {yogurt} ---> {whole milk, other vegetables}:  conf = 0.16, sup = 0.022
# {other vegetables} ---> {whole milk, yogurt}:  conf = 0.115, sup = 0.022
# {whole milk} ---> {other vegetables, yogurt}:  conf = 0.087, sup = 0.022
# {other vegetables, yogurt} ---> {root vegetables}:  conf = 0.297, sup = 0.013
# {yogurt, root vegetables} ---> {other vegetables}:  conf = 0.5, sup = 0.013
# {other vegetables, root vegetables} ---> {yogurt}:  conf = 0.273, sup = 0.013
# {yogurt} ---> {other vegetables, root vegetables}:  conf = 0.093, sup = 0.013
# {other vegetables} ---> {yogurt, root vegetables}:  conf = 0.067, sup = 0.013
# {root vegetables} ---> {other vegetables, yogurt}:  conf = 0.118, sup = 0.013
# {other vegetables, pip fruit} ---> {whole milk}:  conf = 0.518, sup = 0.014
# {whole milk, pip fruit} ---> {other vegetables}:  conf = 0.449, sup = 0.014
# {whole milk, other vegetables} ---> {pip fruit}:  conf = 0.181, sup = 0.014
# {pip fruit} ---> {whole milk, other vegetables}:  conf = 0.179, sup = 0.014
# {other vegetables} ---> {whole milk, pip fruit}:  conf = 0.07, sup = 0.014
# {whole milk} ---> {other vegetables, pip fruit}:  conf = 0.053, sup = 0.014
# {whole milk, other vegetables} ---> {domestic eggs}:  conf = 0.164, sup = 0.012
# {domestic eggs, other vegetables} ---> {whole milk}:  conf = 0.553, sup = 0.012
# {domestic eggs, whole milk} ---> {other vegetables}:  conf = 0.41, sup = 0.012
# {other vegetables} ---> {domestic eggs, whole milk}:  conf = 0.064, sup = 0.012
# {whole milk} ---> {domestic eggs, other vegetables}:  conf = 0.048, sup = 0.012
# {domestic eggs} ---> {whole milk, other vegetables}:  conf = 0.194, sup = 0.012
# {other vegetables, root vegetables} ---> {citrus fruit}:  conf = 0.219, sup = 0.01
# {citrus fruit, root vegetables} ---> {other vegetables}:  conf = 0.586, sup = 0.01
# {citrus fruit, other vegetables} ---> {root vegetables}:  conf = 0.359, sup = 0.01
# {root vegetables} ---> {citrus fruit, other vegetables}:  conf = 0.095, sup = 0.01
# {other vegetables} ---> {citrus fruit, root vegetables}:  conf = 0.054, sup = 0.01
# {citrus fruit} ---> {other vegetables, root vegetables}:  conf = 0.125, sup = 0.01
# {rolls/buns, root vegetables} ---> {whole milk}:  conf = 0.523, sup = 0.013
# {whole milk, rolls/buns} ---> {root vegetables}:  conf = 0.224, sup = 0.013
# {whole milk, root vegetables} ---> {rolls/buns}:  conf = 0.26, sup = 0.013
# {rolls/buns} ---> {whole milk, root vegetables}:  conf = 0.069, sup = 0.013
# {root vegetables} ---> {whole milk, rolls/buns}:  conf = 0.117, sup = 0.013
# {whole milk} ---> {rolls/buns, root vegetables}:  conf = 0.05, sup = 0.013
# {other vegetables, rolls/buns} ---> {whole milk}:  conf = 0.42, sup = 0.018
# {whole milk, rolls/buns} ---> {other vegetables}:  conf = 0.316, sup = 0.018
# {whole milk, other vegetables} ---> {rolls/buns}:  conf = 0.239, sup = 0.018
# {rolls/buns} ---> {whole milk, other vegetables}:  conf = 0.097, sup = 0.018
# {other vegetables} ---> {whole milk, rolls/buns}:  conf = 0.092, sup = 0.018
# {whole milk} ---> {other vegetables, rolls/buns}:  conf = 0.07, sup = 0.018
# {tropical fruit, rolls/buns} ---> {whole milk}:  conf = 0.446, sup = 0.011
# {whole milk, rolls/buns} ---> {tropical fruit}:  conf = 0.194, sup = 0.011
# {whole milk, tropical fruit} ---> {rolls/buns}:  conf = 0.26, sup = 0.011
# {rolls/buns} ---> {whole milk, tropical fruit}:  conf = 0.06, sup = 0.011
# {tropical fruit} ---> {whole milk, rolls/buns}:  conf = 0.105, sup = 0.011
# {whole milk} ---> {tropical fruit, rolls/buns}:  conf = 0.043, sup = 0.011
# {tropical fruit, root vegetables} ---> {whole milk}:  conf = 0.57, sup = 0.012
# {whole milk, root vegetables} ---> {tropical fruit}:  conf = 0.245, sup = 0.012
# {whole milk, tropical fruit} ---> {root vegetables}:  conf = 0.284, sup = 0.012
# {root vegetables} ---> {whole milk, tropical fruit}:  conf = 0.11, sup = 0.012
# {tropical fruit} ---> {whole milk, root vegetables}:  conf = 0.114, sup = 0.012
# {whole milk} ---> {tropical fruit, root vegetables}:  conf = 0.047, sup = 0.012
# {whole milk, root vegetables} ---> {yogurt}:  conf = 0.297, sup = 0.015
# {root vegetables, yogurt} ---> {whole milk}:  conf = 0.563, sup = 0.015
# {whole milk, yogurt} ---> {root vegetables}:  conf = 0.26, sup = 0.015
# {root vegetables} ---> {whole milk, yogurt}:  conf = 0.133, sup = 0.015
# {whole milk} ---> {root vegetables, yogurt}:  conf = 0.057, sup = 0.015
# {yogurt} ---> {whole milk, root vegetables}:  conf = 0.104, sup = 0.015
# {whole milk, soda} ---> {yogurt}:  conf = 0.261, sup = 0.01
# {soda, yogurt} ---> {whole milk}:  conf = 0.383, sup = 0.01
# {whole milk, yogurt} ---> {soda}:  conf = 0.187, sup = 0.01
# {soda} ---> {whole milk, yogurt}:  conf = 0.06, sup = 0.01
# {whole milk} ---> {soda, yogurt}:  conf = 0.041, sup = 0.01
# {yogurt} ---> {whole milk, soda}:  conf = 0.075, sup = 0.01
# {whipped/sour cream, other vegetables} ---> {whole milk}:  conf = 0.507, sup = 0.015
# {whole milk, other vegetables} ---> {whipped/sour cream}:  conf = 0.196, sup = 0.015
# {whole milk, whipped/sour cream} ---> {other vegetables}:  conf = 0.454, sup = 0.015
# {other vegetables} ---> {whole milk, whipped/sour cream}:  conf = 0.076, sup = 0.015
# {whipped/sour cream} ---> {whole milk, other vegetables}:  conf = 0.204, sup = 0.015
# {whole milk} ---> {whipped/sour cream, other vegetables}:  conf = 0.057, sup = 0.015
# {pork, other vegetables} ---> {whole milk}:  conf = 0.469, sup = 0.01
# {whole milk, other vegetables} ---> {pork}:  conf = 0.136, sup = 0.01
# {whole milk, pork} ---> {other vegetables}:  conf = 0.459, sup = 0.01
# {other vegetables} ---> {whole milk, pork}:  conf = 0.053, sup = 0.01
# {pork} ---> {whole milk, other vegetables}:  conf = 0.176, sup = 0.01
# {whole milk} ---> {pork, other vegetables}:  conf = 0.04, sup = 0.01
# {other vegetables, soda} ---> {whole milk}:  conf = 0.425, sup = 0.014
# {whole milk, soda} ---> {other vegetables}:  conf = 0.348, sup = 0.014
# {whole milk, other vegetables} ---> {soda}:  conf = 0.186, sup = 0.014
# {soda} ---> {whole milk, other vegetables}:  conf = 0.08, sup = 0.014
# {other vegetables} ---> {whole milk, soda}:  conf = 0.072, sup = 0.014
# {whole milk} ---> {other vegetables, soda}:  conf = 0.055, sup = 0.014
# {other vegetables, root vegetables} ---> {whole milk}:  conf = 0.489, sup = 0.023
# {whole milk, root vegetables} ---> {other vegetables}:  conf = 0.474, sup = 0.023
# {whole milk, other vegetables} ---> {root vegetables}:  conf = 0.31, sup = 0.023
# {root vegetables} ---> {whole milk, other vegetables}:  conf = 0.213, sup = 0.023
# {other vegetables} ---> {whole milk, root vegetables}:  conf = 0.12, sup = 0.023
# {whole milk} ---> {other vegetables, root vegetables}:  conf = 0.091, sup = 0.023
# {other vegetables, root vegetables} ---> {rolls/buns}:  conf = 0.258, sup = 0.012
# {root vegetables, rolls/buns} ---> {other vegetables}:  conf = 0.502, sup = 0.012
# {other vegetables, rolls/buns} ---> {root vegetables}:  conf = 0.286, sup = 0.012
# {root vegetables} ---> {other vegetables, rolls/buns}:  conf = 0.112, sup = 0.012
# {other vegetables} ---> {root vegetables, rolls/buns}:  conf = 0.063, sup = 0.012
# {rolls/buns} ---> {other vegetables, root vegetables}:  conf = 0.066, sup = 0.012
# {other vegetables, root vegetables} ---> {tropical fruit}:  conf = 0.26, sup = 0.012
# {tropical fruit, root vegetables} ---> {other vegetables}:  conf = 0.585, sup = 0.012
# {other vegetables, tropical fruit} ---> {root vegetables}:  conf = 0.343, sup = 0.012
# {root vegetables} ---> {other vegetables, tropical fruit}:  conf = 0.113, sup = 0.012
# {other vegetables} ---> {tropical fruit, root vegetables}:  conf = 0.064, sup = 0.012
# {tropical fruit} ---> {other vegetables, root vegetables}:  conf = 0.117, sup = 0.012
# {whole milk, curd} ---> {yogurt}:  conf = 0.385, sup = 0.01
# {curd, yogurt} ---> {whole milk}:  conf = 0.582, sup = 0.01
# {whole milk, yogurt} ---> {curd}:  conf = 0.18, sup = 0.01
# {curd} ---> {whole milk, yogurt}:  conf = 0.189, sup = 0.01
# {whole milk} ---> {curd, yogurt}:  conf = 0.039, sup = 0.01
# {yogurt} ---> {whole milk, curd}:  conf = 0.072, sup = 0.01
# {tropical fruit, yogurt} ---> {whole milk}:  conf = 0.517, sup = 0.015
# {whole milk, yogurt} ---> {tropical fruit}:  conf = 0.27, sup = 0.015
# {whole milk, tropical fruit} ---> {yogurt}:  conf = 0.358, sup = 0.015
# {yogurt} ---> {whole milk, tropical fruit}:  conf = 0.109, sup = 0.015
# {tropical fruit} ---> {whole milk, yogurt}:  conf = 0.144, sup = 0.015
# {whole milk} ---> {tropical fruit, yogurt}:  conf = 0.059, sup = 0.015
# {whole milk, yogurt} ---> {citrus fruit}:  conf = 0.183, sup = 0.01
# {citrus fruit, yogurt} ---> {whole milk}:  conf = 0.474, sup = 0.01
# {citrus fruit, whole milk} ---> {yogurt}:  conf = 0.337, sup = 0.01
# {yogurt} ---> {citrus fruit, whole milk}:  conf = 0.074, sup = 0.01
# {whole milk} ---> {citrus fruit, yogurt}:  conf = 0.04, sup = 0.01
# {citrus fruit} ---> {whole milk, yogurt}:  conf = 0.124, sup = 0.01

# %%
#selecting those that are frequent using Apriori - experimenting with min_support parameter 0.0234
Fi_1,Frequent_items_1 = apriori(dataset, min_support=0.0234, verbose=True)
# Out:
# {meat}:  sup = 0.026
# {sliced cheese}:  sup = 0.025
# {onions}:  sup = 0.031
# {frozen meals}:  sup = 0.028
# {specialty chocolate}:  sup = 0.03
# {frozen vegetables}:  sup = 0.048
# {ice cream}:  sup = 0.025
# {oil}:  sup = 0.028
# {ham}:  sup = 0.026
# {hard cheese}:  sup = 0.025
# {misc. beverages}:  sup = 0.028
# {domestic eggs}:  sup = 0.063
# {dessert}:  sup = 0.037
# {whipped/sour cream}:  sup = 0.072
# {pork}:  sup = 0.058
# {berries}:  sup = 0.033
# {napkins}:  sup = 0.052
# {hygiene articles}:  sup = 0.033
# {hamburger meat}:  sup = 0.033
# {beverages}:  sup = 0.026
# {shopping bags}:  sup = 0.099
# {brown bread}:  sup = 0.065
# {sausage}:  sup = 0.094
# {canned beer}:  sup = 0.078
# {waffles}:  sup = 0.038
# {salty snack}:  sup = 0.038
# {root vegetables}:  sup = 0.109
# {candy}:  sup = 0.03
# {pastry}:  sup = 0.089
# {butter milk}:  sup = 0.028
# {specialty bar}:  sup = 0.027
# {sugar}:  sup = 0.034
# {newspapers}:  sup = 0.08
# {fruit/vegetable juice}:  sup = 0.072
# {chicken}:  sup = 0.043
# {soda}:  sup = 0.174
# {frankfurter}:  sup = 0.059
# {beef}:  sup = 0.052
# {curd}:  sup = 0.053
# {white bread}:  sup = 0.042
# {chocolate}:  sup = 0.05
# {bottled water}:  sup = 0.111
# {bottled beer}:  sup = 0.081
# {UHT-milk}:  sup = 0.033
# {rolls/buns}:  sup = 0.184
# {butter}:  sup = 0.055
# {other vegetables}:  sup = 0.193
# {long life bakery product}:  sup = 0.037
# {pip fruit}:  sup = 0.076
# {cream cheese}:  sup = 0.04
# {whole milk}:  sup = 0.256
# {yogurt}:  sup = 0.14
# {tropical fruit}:  sup = 0.105
# {coffee}:  sup = 0.058
# {margarine}:  sup = 0.059
# {citrus fruit}:  sup = 0.083
# {other vegetables, yogurt}:  sup = 0.043
# {other vegetables, pip fruit}:  sup = 0.026
# {sausage, other vegetables}:  sup = 0.027
# {whole milk, shopping bags}:  sup = 0.025
# {citrus fruit, other vegetables}:  sup = 0.029
# {whole milk, fruit/vegetable juice}:  sup = 0.027
# {whole milk, newspapers}:  sup = 0.027
# {margarine, whole milk}:  sup = 0.024
# {whole milk, pip fruit}:  sup = 0.03
# {whole milk, rolls/buns}:  sup = 0.057
# {sausage, whole milk}:  sup = 0.03
# {yogurt, rolls/buns}:  sup = 0.034
# {bottled water, soda}:  sup = 0.029
# {yogurt, soda}:  sup = 0.027
# {whole milk, pastry}:  sup = 0.033
# {yogurt, root vegetables}:  sup = 0.026
# {brown bread, whole milk}:  sup = 0.025
# {domestic eggs, whole milk}:  sup = 0.03
# {whole milk, soda}:  sup = 0.04
# {other vegetables, soda}:  sup = 0.033
# {whole milk, whipped/sour cream}:  sup = 0.032
# {whipped/sour cream, other vegetables}:  sup = 0.029
# {whole milk, root vegetables}:  sup = 0.049
# {bottled water, rolls/buns}:  sup = 0.024
# {soda, shopping bags}:  sup = 0.025
# {sausage, rolls/buns}:  sup = 0.031
# {sausage, soda}:  sup = 0.024
# {tropical fruit, rolls/buns}:  sup = 0.025
# {other vegetables, root vegetables}:  sup = 0.047
# {rolls/buns, root vegetables}:  sup = 0.024
# {rolls/buns, soda}:  sup = 0.038
# {citrus fruit, whole milk}:  sup = 0.031
# {whole milk, tropical fruit}:  sup = 0.042
# {whole milk, bottled water}:  sup = 0.034
# {whole milk, curd}:  sup = 0.026
# {tropical fruit, other vegetables}:  sup = 0.036
# {other vegetables, bottled water}:  sup = 0.025
# {other vegetables, rolls/buns}:  sup = 0.043
# {whole milk, yogurt}:  sup = 0.056
# {butter, whole milk}:  sup = 0.028
# {whole milk, other vegetables}:  sup = 0.075
# {tropical fruit, yogurt}:  sup = 0.029

# %%
#listing association rules derived
Association = generate_rules(Fi_1, Frequent_items_1, min_confidence=0.2, verbose=True)
# Out:
# {yogurt} ---> {other vegetables}:  conf = 0.311, sup = 0.043
# {other vegetables} ---> {yogurt}:  conf = 0.224, sup = 0.043
# {pip fruit} ---> {other vegetables}:  conf = 0.345, sup = 0.026
# {sausage} ---> {other vegetables}:  conf = 0.287, sup = 0.027
# {shopping bags} ---> {whole milk}:  conf = 0.249, sup = 0.025
# {citrus fruit} ---> {other vegetables}:  conf = 0.349, sup = 0.029
# {fruit/vegetable juice} ---> {whole milk}:  conf = 0.368, sup = 0.027
# {newspapers} ---> {whole milk}:  conf = 0.343, sup = 0.027
# {margarine} ---> {whole milk}:  conf = 0.413, sup = 0.024
# {pip fruit} ---> {whole milk}:  conf = 0.398, sup = 0.03
# {rolls/buns} ---> {whole milk}:  conf = 0.308, sup = 0.057
# {whole milk} ---> {rolls/buns}:  conf = 0.222, sup = 0.057
# {sausage} ---> {whole milk}:  conf = 0.318, sup = 0.03
# {yogurt} ---> {rolls/buns}:  conf = 0.246, sup = 0.034
# {bottled water} ---> {soda}:  conf = 0.262, sup = 0.029
# {pastry} ---> {whole milk}:  conf = 0.374, sup = 0.033
# {root vegetables} ---> {yogurt}:  conf = 0.237, sup = 0.026
# {brown bread} ---> {whole milk}:  conf = 0.389, sup = 0.025
# {domestic eggs} ---> {whole milk}:  conf = 0.473, sup = 0.03
# {soda} ---> {whole milk}:  conf = 0.23, sup = 0.04
# {whipped/sour cream} ---> {whole milk}:  conf = 0.45, sup = 0.032
# {whipped/sour cream} ---> {other vegetables}:  conf = 0.403, sup = 0.029
# {root vegetables} ---> {whole milk}:  conf = 0.449, sup = 0.049
# {bottled water} ---> {rolls/buns}:  conf = 0.219, sup = 0.024
# {shopping bags} ---> {soda}:  conf = 0.25, sup = 0.025
# {sausage} ---> {rolls/buns}:  conf = 0.326, sup = 0.031
# {sausage} ---> {soda}:  conf = 0.259, sup = 0.024
# {tropical fruit} ---> {rolls/buns}:  conf = 0.234, sup = 0.025
# {root vegetables} ---> {other vegetables}:  conf = 0.435, sup = 0.047
# {other vegetables} ---> {root vegetables}:  conf = 0.245, sup = 0.047
# {root vegetables} ---> {rolls/buns}:  conf = 0.223, sup = 0.024
# {soda} ---> {rolls/buns}:  conf = 0.22, sup = 0.038
# {rolls/buns} ---> {soda}:  conf = 0.208, sup = 0.038
# {citrus fruit} ---> {whole milk}:  conf = 0.369, sup = 0.031
# {tropical fruit} ---> {whole milk}:  conf = 0.403, sup = 0.042
# {bottled water} ---> {whole milk}:  conf = 0.311, sup = 0.034
# {curd} ---> {whole milk}:  conf = 0.49, sup = 0.026
# {tropical fruit} ---> {other vegetables}:  conf = 0.342, sup = 0.036
# {bottled water} ---> {other vegetables}:  conf = 0.224, sup = 0.025
# {rolls/buns} ---> {other vegetables}:  conf = 0.232, sup = 0.043
# {other vegetables} ---> {rolls/buns}:  conf = 0.22, sup = 0.043
# {yogurt} ---> {whole milk}:  conf = 0.402, sup = 0.056
# {whole milk} ---> {yogurt}:  conf = 0.219, sup = 0.056
# {butter} ---> {whole milk}:  conf = 0.497, sup = 0.028
# {other vegetables} ---> {whole milk}:  conf = 0.387, sup = 0.075
# {whole milk} ---> {other vegetables}:  conf = 0.293, sup = 0.075
# {yogurt} ---> {tropical fruit}:  conf = 0.21, sup = 0.029
# {tropical fruit} ---> {yogurt}:  conf = 0.279, sup = 0.029

# %% [markdown]
# <h3> Inference </h3><br>
# <b>Stats</b><br>
# min_support, min_confidence 0.01 --> too many records<br>
# min_support - 0.1 --> 6 records, min_confidence- 0.1 --> no records<br>
# min_support - 0.0234, min_confidence 0.2 --> few records<br>
#
# As suggested it is hard to find itemsets with high supports, so experimented with some low supports.<br>
#  -->when the min_support was 0.01, we have many records and one of them is
#
#  {rolls/buns} ---> {coffee}:  conf = 0.06, sup = 0.011
#
# -->The above record cannot be found when it is min_support = 0.1 or min_support = 0.0234.
#
# --> Also,{yogurt} ---> {other vegetables} seems to be a favorite combination of many. It appears with both min_support = 0.1 and min_support = 0.0234.

# %% [markdown]
# # FP-Growth

# %%
# (c) 2014 Reid Johnson
#
# Modified from:
# Eric Naeseth <eric@naeseth.com>
# (https://github.com/enaeseth/python-fp-growth/blob/master/fp_growth.py)
#
# A Python implementation of the FP-growth algorithm.

from collections import defaultdict, namedtuple
#from itertools import imap

__author__ = 'Eric Naeseth <eric@naeseth.com>'
__copyright__ = 'Copyright © 2009 Eric Naeseth'
__license__ = 'MIT License'

def fpgrowth(dataset, min_support=0.5, include_support=True, verbose=False):
    """Implements the FP-growth algorithm.

    The `dataset` parameter can be any iterable of iterables of items.
    `min_support` should be an integer specifying the minimum number of
    occurrences of an itemset for it to be accepted.

    Each item must be hashable (i.e., it must be valid as a member of a
    dictionary or a set).

    If `include_support` is true, yield (itemset, support) pairs instead of
    just the itemsets.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    include_support : bool
        Include support in output (default=False).

    References
    ----------
    .. [1] J. Han, J. Pei, Y. Yin, "Mining Frequent Patterns without Candidate 
           Generation," 2000.

    """

    F = []
    support_data = {}
    for k,v in find_frequent_itemsets(dataset, min_support=min_support, include_support=include_support, verbose=verbose):
        F.append(frozenset(k))
        support_data[frozenset(k)] = v

    # Create one array with subarrays that hold all transactions of equal length.
    def bucket_list(nested_list, sort=True):
        bucket = defaultdict(list)
        for sublist in nested_list:
            bucket[len(sublist)].append(sublist)
        return [v for k,v in sorted(bucket.items())] if sort else bucket.values()

    F = bucket_list(F)
    
    return F, support_data

def find_frequent_itemsets(dataset, min_support, include_support=False, verbose=False):
    """
    Find frequent itemsets in the given transactions using FP-growth. This
    function returns a generator instead of an eagerly-populated list of items.

    The `dataset` parameter can be any iterable of iterables of items.
    `min_support` should be an integer specifying the minimum number of
    occurrences of an itemset for it to be accepted.

    Each item must be hashable (i.e., it must be valid as a member of a
    dictionary or a set).

    If `include_support` is true, yield (itemset, support) pairs instead of
    just the itemsets.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    include_support : bool
        Include support in output (default=False).

    """
    items = defaultdict(lambda: 0) # mapping from items to their supports
    processed_transactions = []

    # Load the passed-in transactions and count the support that individual
    # items have.
    for transaction in dataset:
        processed = []
        for item in transaction:
            items[item] += 1
            processed.append(item)
        processed_transactions.append(processed)

    # Remove infrequent items from the item support dictionary.
    items = dict((item, support) for item, support in items.items()
        if support >= min_support)

    # Build our FP-tree. Before any transactions can be added to the tree, they
    # must be stripped of infrequent items and their surviving items must be
    # sorted in decreasing order of frequency.
    def clean_transaction(transaction):
        #transaction = filter(lambda v: v in items, transaction)
        transaction.sort(key=lambda v: items[v], reverse=True)
        return transaction

    master = FPTree()
    for transaction in map(clean_transaction, processed_transactions):
        master.add(transaction)

    support_data = {}
    def find_with_suffix(tree, suffix):
        for item, nodes in tree.items():
            support = float(sum(n.count for n in nodes)) / len(dataset)
            if support >= min_support and item not in suffix:
                # New winner!
                found_set = [item] + suffix
                support_data[frozenset(found_set)] = support
                yield (found_set, support) if include_support else found_set

                # Build a conditional tree and recursively search for frequent
                # itemsets within it.
                cond_tree = conditional_tree_from_paths(tree.prefix_paths(item),
                    min_support)
                for s in find_with_suffix(cond_tree, found_set):
                    yield s # pass along the good news to our caller

    if verbose:
        # Print a list of all the frequent itemsets.
        for itemset, support in find_with_suffix(master, []):
            print("" \
                + "{" \
                + "".join(str(i) + ", " for i in iter(itemset)).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(round(support_data[frozenset(itemset)], 3)))

    # Search for frequent itemsets, and yield the results we find.
    for itemset in find_with_suffix(master, []):
        yield itemset

class FPTree(object):
    """
    An FP tree.

    This object may only store transaction items that are hashable (i.e., all
    items must be valid as dictionary keys or set members).
    """

    Route = namedtuple('Route', 'head tail')

    def __init__(self):
        # The root node of the tree.
        self._root = FPNode(self, None, None)

        # A dictionary mapping items to the head and tail of a path of
        # "neighbors" that will hit every node containing that item.
        self._routes = {}

    @property
    def root(self):
        """The root node of the tree."""
        return self._root

    def add(self, transaction):
        """
        Adds a transaction to the tree.
        """

        point = self._root

        for item in transaction:
            next_point = point.search(item)
            if next_point:
                # There is already a node in this tree for the current
                # transaction item; reuse it.
                next_point.increment()
            else:
                # Create a new point and add it as a child of the point we're
                # currently looking at.
                next_point = FPNode(self, item)
                point.add(next_point)

                # Update the route of nodes that contain this item to include
                # our new node.
                self._update_route(next_point)

            point = next_point

    def _update_route(self, point):
        """Add the given node to the route through all nodes for its item."""
        assert self is point.tree

        try:
            route = self._routes[point.item]
            route[1].neighbor = point # route[1] is the tail
            self._routes[point.item] = self.Route(route[0], point)
        except KeyError:
            # First node for this item; start a new route.
            self._routes[point.item] = self.Route(point, point)

    def items(self):
        """
        Generate one 2-tuples for each item represented in the tree. The first
        element of the tuple is the item itself, and the second element is a
        generator that will yield the nodes in the tree that belong to the item.
        """
        for item in self._routes.keys():
            yield (item, self.nodes(item))

            
    def nodes(self, item):
        """
        Generates the sequence of nodes that contain the given item.
        """

        try:
            node = self._routes[item][0]
        except KeyError:
            return

        while node:
            yield node
            node = node.neighbor

    def prefix_paths(self, item):
        """Generates the prefix paths that end with the given item."""

        def collect_path(node):
            path = []
            while node and not node.root:
                path.append(node)
                node = node.parent
            path.reverse()
            return path

        return (collect_path(node) for node in self.nodes(item))

    def inspect(self):
        print("Tree:")
        self.root.inspect(1)

        print("")
        print("Routes:")
        for item, nodes in self.items():
            print("  %r" % item)
            for node in nodes:
                print("    %r" % node)

    def _removed(self, node):
        """Called when `node` is removed from the tree; performs cleanup."""

        head, tail = self._routes[node.item]
        if node is head:
            if node is tail or not node.neighbor:
                # It was the sole node.
                del self._routes[node.item]
            else:
                self._routes[node.item] = self.Route(node.neighbor, tail)
        else:
            for n in self.nodes(node.item):
                if n.neighbor is node:
                    n.neighbor = node.neighbor # skip over
                    if node is tail:
                        self._routes[node.item] = self.Route(head, n)
                    break

def conditional_tree_from_paths(paths, min_support):
    """Builds a conditional FP-tree from the given prefix paths."""
    tree = FPTree()
    condition_item = None
    items = set()

    # Import the nodes in the paths into the new tree. Only the counts of the
    # leaf notes matter; the remaining counts will be reconstructed from the
    # leaf counts.
    for path in paths:
        if condition_item is None:
            condition_item = path[-1].item

        point = tree.root
        for node in path:
            next_point = point.search(node.item)
            if not next_point:
                # Add a new node to the tree.
                items.add(node.item)
                count = node.count if node.item == condition_item else 0
                next_point = FPNode(tree, node.item, count)
                point.add(next_point)
                tree._update_route(next_point)
            point = next_point

    assert condition_item is not None

    # Calculate the counts of the non-leaf nodes.
    for path in tree.prefix_paths(condition_item):
        count = path[-1].count
        for node in reversed(path[:-1]):
            node._count += count

    # Eliminate the nodes for any items that are no longer frequent.
    for item in items:
        support = sum(n.count for n in tree.nodes(item))
        if support < min_support:
            # Doesn't make the cut anymore
            for node in tree.nodes(item):
                if node.parent is not None:
                    node.parent.remove(node)

    # Finally, remove the nodes corresponding to the item for which this
    # conditional tree was generated.
    for node in tree.nodes(condition_item):
        if node.parent is not None: # the node might already be an orphan
            node.parent.remove(node)

    return tree

class FPNode(object):
    """A node in an FP tree."""

    def __init__(self, tree, item, count=1):
        self._tree = tree
        self._item = item
        self._count = count
        self._parent = None
        self._children = {}
        self._neighbor = None

    def add(self, child):
        """Adds the given FPNode `child` as a child of this node."""

        if not isinstance(child, FPNode):
            raise TypeError("Can only add other FPNodes as children")

        if not child.item in self._children:
            self._children[child.item] = child
            child.parent = self

    def search(self, item):
        """
        Checks to see if this node contains a child node for the given item.
        If so, that node is returned; otherwise, `None` is returned.
        """

        try:
            return self._children[item]
        except KeyError:
            return None

    def remove(self, child):
        try:
            if self._children[child.item] is child:
                del self._children[child.item]
                child.parent = None
                self._tree._removed(child)
                for sub_child in child.children:
                    try:
                        # Merger case: we already have a child for that item, so
                        # add the sub-child's count to our child's count.
                        self._children[sub_child.item]._count += sub_child.count
                        sub_child.parent = None # it's an orphan now
                    except KeyError:
                        # Turns out we don't actually have a child, so just add
                        # the sub-child as our own child.
                        self.add(sub_child)
                child._children = {}
            else:
                raise ValueError("that node is not a child of this node")
        except KeyError:
            raise ValueError("that node is not a child of this node")

    def __contains__(self, item):
        return item in self._children

    @property
    def tree(self):
        """The tree in which this node appears."""
        return self._tree

    @property
    def item(self):
        """The item contained in this node."""
        return self._item

    @property
    def count(self):
        """The count associated with this node's item."""
        return self._count

    def increment(self):
        """Increments the count associated with this node's item."""
        if self._count is None:
            raise ValueError("Root nodes have no associated count.")
        self._count += 1

    @property
    def root(self):
        """True if this node is the root of a tree; false if otherwise."""
        return self._item is None and self._count is None

    @property
    def leaf(self):
        """True if this node is a leaf in the tree; false if otherwise."""
        return len(self._children) == 0

    def parent():
        doc = "The node's parent."
        def fget(self):
            return self._parent
        def fset(self, value):
            if value is not None and not isinstance(value, FPNode):
                raise TypeError("A node must have an FPNode as a parent.")
            if value and value.tree is not self.tree:
                raise ValueError("Cannot have a parent from another tree.")
            self._parent = value
        return locals()
    parent = property(**parent())

    def neighbor():
        doc = """
        The node's neighbor; the one with the same value that is "to the right"
        of it in the tree.
        """
        def fget(self):
            return self._neighbor
        def fset(self, value):
            if value is not None and not isinstance(value, FPNode):
                raise TypeError("A node must have an FPNode as a neighbor.")
            if value and value.tree is not self.tree:
                raise ValueError("Cannot have a neighbor from another tree.")
            self._neighbor = value
        return locals()
    neighbor = property(**neighbor())

    @property
    def children(self):
        """The nodes that are children of this node."""
        return tuple(self._children.values())
        
    def inspect(self, depth=0):
        print(('  ' * depth) + repr(self))
        for child in self.children:
            child.inspect(depth + 1)

    def __repr__(self):
        if self.root:
            return "<%s (root)>" % type(self).__name__
        return "<%s %r (%r)>" % (type(self).__name__, self.item, self.count)

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1,  support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([item]) for item in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# %%
# selecting those that are frequent items -  using FP-Growth
Fi_fp, Frequent_items_fp = fpgrowth(dataset, min_support=0.01, verbose=True)
# Out:
# {citrus fruit}:  sup = 0.083
# {whole milk, citrus fruit}:  sup = 0.031
# {yogurt, citrus fruit}:  sup = 0.022
# {whole milk, yogurt, citrus fruit}:  sup = 0.01
# {bottled water, citrus fruit}:  sup = 0.014
# {tropical fruit, citrus fruit}:  sup = 0.02
# {other vegetables, citrus fruit}:  sup = 0.029
# {whole milk, other vegetables, citrus fruit}:  sup = 0.013
# {root vegetables, citrus fruit}:  sup = 0.018
# {other vegetables, root vegetables, citrus fruit}:  sup = 0.01
# {sausage, citrus fruit}:  sup = 0.011
# {rolls/buns, citrus fruit}:  sup = 0.017
# {soda, citrus fruit}:  sup = 0.013
# {margarine}:  sup = 0.059
# {other vegetables, margarine}:  sup = 0.02
# {whole milk, margarine}:  sup = 0.024
# {rolls/buns, margarine}:  sup = 0.015
# {root vegetables, margarine}:  sup = 0.011
# {bottled water, margarine}:  sup = 0.01
# {yogurt, margarine}:  sup = 0.014
# {soda, margarine}:  sup = 0.01
# {semi-finished bread}:  sup = 0.018
# {yogurt}:  sup = 0.14
# {whole milk, yogurt}:  sup = 0.056
# {soda, yogurt}:  sup = 0.027
# {whole milk, soda, yogurt}:  sup = 0.01
# {rolls/buns, yogurt}:  sup = 0.034
# {whole milk, rolls/buns, yogurt}:  sup = 0.016
# {other vegetables, rolls/buns, yogurt}:  sup = 0.011
# {other vegetables, yogurt}:  sup = 0.043
# {whole milk, other vegetables, yogurt}:  sup = 0.022
# {tropical fruit}:  sup = 0.105
# {yogurt, tropical fruit}:  sup = 0.029
# {whole milk, yogurt, tropical fruit}:  sup = 0.015
# {other vegetables, yogurt, tropical fruit}:  sup = 0.012
# {other vegetables, tropical fruit}:  sup = 0.036
# {whole milk, other vegetables, tropical fruit}:  sup = 0.017
# {bottled water, tropical fruit}:  sup = 0.019
# {whole milk, tropical fruit}:  sup = 0.042
# {rolls/buns, tropical fruit}:  sup = 0.025
# {whole milk, rolls/buns, tropical fruit}:  sup = 0.011
# {root vegetables, tropical fruit}:  sup = 0.021
# {other vegetables, root vegetables, tropical fruit}:  sup = 0.012
# {whole milk, root vegetables, tropical fruit}:  sup = 0.012
# {soda, tropical fruit}:  sup = 0.021
# {coffee}:  sup = 0.058
# {whole milk, coffee}:  sup = 0.019
# {other vegetables, coffee}:  sup = 0.013
# {rolls/buns, coffee}:  sup = 0.011
# {whole milk}:  sup = 0.256
# {pip fruit}:  sup = 0.076
# {yogurt, pip fruit}:  sup = 0.018
# {whole milk, pip fruit}:  sup = 0.03
# {rolls/buns, pip fruit}:  sup = 0.014
# {tropical fruit, pip fruit}:  sup = 0.02
# {sausage, pip fruit}:  sup = 0.011
# {citrus fruit, pip fruit}:  sup = 0.014
# {other vegetables, pip fruit}:  sup = 0.026
# {whole milk, other vegetables, pip fruit}:  sup = 0.014
# {root vegetables, pip fruit}:  sup = 0.016
# {bottled water, pip fruit}:  sup = 0.011
# {soda, pip fruit}:  sup = 0.013
# {pastry, pip fruit}:  sup = 0.011
# {cream cheese}:  sup = 0.04
# {yogurt, cream cheese}:  sup = 0.012
# {whole milk, cream cheese}:  sup = 0.016
# {other vegetables, cream cheese}:  sup = 0.014
# {other vegetables}:  sup = 0.193
# {whole milk, other vegetables}:  sup = 0.075
# {long life bakery product}:  sup = 0.037
# {whole milk, long life bakery product}:  sup = 0.014
# {other vegetables, long life bakery product}:  sup = 0.011
# {condensed milk}:  sup = 0.01
# {butter}:  sup = 0.055
# {whole milk, butter}:  sup = 0.028
# {yogurt, butter}:  sup = 0.015
# {other vegetables, butter}:  sup = 0.02
# {whole milk, other vegetables, butter}:  sup = 0.011
# {rolls/buns, butter}:  sup = 0.013
# {root vegetables, butter}:  sup = 0.013
# {whipped/sour cream, butter}:  sup = 0.01
# {rolls/buns}:  sup = 0.184
# {other vegetables, rolls/buns}:  sup = 0.043
# {whole milk, other vegetables, rolls/buns}:  sup = 0.018
# {whole milk, rolls/buns}:  sup = 0.057
# {bottled beer}:  sup = 0.081
# {other vegetables, bottled beer}:  sup = 0.016
# {rolls/buns, bottled beer}:  sup = 0.014
# {bottled water, bottled beer}:  sup = 0.016
# {soda, bottled beer}:  sup = 0.017
# {whole milk, bottled beer}:  sup = 0.02
# {UHT-milk}:  sup = 0.033
# {pot plants}:  sup = 0.017
# {bottled water}:  sup = 0.111
# {other vegetables, bottled water}:  sup = 0.025
# {whole milk, other vegetables, bottled water}:  sup = 0.011
# {whole milk, bottled water}:  sup = 0.034
# {yogurt, bottled water}:  sup = 0.023
# {rolls/buns, bottled water}:  sup = 0.024
# {soda, bottled water}:  sup = 0.029
# {chocolate}:  sup = 0.05
# {other vegetables, chocolate}:  sup = 0.013
# {rolls/buns, chocolate}:  sup = 0.012
# {soda, chocolate}:  sup = 0.014
# {whole milk, chocolate}:  sup = 0.017
# {white bread}:  sup = 0.042
# {other vegetables, white bread}:  sup = 0.014
# {whole milk, white bread}:  sup = 0.017
# {soda, white bread}:  sup = 0.01
# {curd}:  sup = 0.053
# {whole milk, curd}:  sup = 0.026
# {yogurt, curd}:  sup = 0.017
# {whole milk, yogurt, curd}:  sup = 0.01
# {tropical fruit, curd}:  sup = 0.01
# {other vegetables, curd}:  sup = 0.017
# {rolls/buns, curd}:  sup = 0.01
# {root vegetables, curd}:  sup = 0.011
# {whipped/sour cream, curd}:  sup = 0.01
# {dishes}:  sup = 0.018
# {flour}:  sup = 0.017
# {beef}:  sup = 0.052
# {rolls/buns, beef}:  sup = 0.014
# {whole milk, beef}:  sup = 0.021
# {root vegetables, beef}:  sup = 0.017
# {other vegetables, beef}:  sup = 0.02
# {yogurt, beef}:  sup = 0.012
# {soda}:  sup = 0.174
# {rolls/buns, soda}:  sup = 0.038
# {whole milk, soda}:  sup = 0.04
# {other vegetables, soda}:  sup = 0.033
# {whole milk, other vegetables, soda}:  sup = 0.014
# {frankfurter}:  sup = 0.059
# {rolls/buns, frankfurter}:  sup = 0.019
# {soda, frankfurter}:  sup = 0.011
# {whole milk, frankfurter}:  sup = 0.021
# {other vegetables, frankfurter}:  sup = 0.016
# {root vegetables, frankfurter}:  sup = 0.01
# {sausage, frankfurter}:  sup = 0.01
# {yogurt, frankfurter}:  sup = 0.011
# {chicken}:  sup = 0.043
# {other vegetables, chicken}:  sup = 0.018
# {root vegetables, chicken}:  sup = 0.011
# {whole milk, chicken}:  sup = 0.018
# {newspapers}:  sup = 0.08
# {tropical fruit, newspapers}:  sup = 0.012
# {soda, newspapers}:  sup = 0.015
# {rolls/buns, newspapers}:  sup = 0.02
# {yogurt, newspapers}:  sup = 0.015
# {bottled water, newspapers}:  sup = 0.011
# {whole milk, newspapers}:  sup = 0.027
# {other vegetables, newspapers}:  sup = 0.019
# {root vegetables, newspapers}:  sup = 0.011
# {fruit/vegetable juice}:  sup = 0.072
# {soda, fruit/vegetable juice}:  sup = 0.018
# {shopping bags, fruit/vegetable juice}:  sup = 0.011
# {other vegetables, fruit/vegetable juice}:  sup = 0.021
# {whole milk, other vegetables, fruit/vegetable juice}:  sup = 0.01
# {tropical fruit, fruit/vegetable juice}:  sup = 0.014
# {bottled water, fruit/vegetable juice}:  sup = 0.014
# {whole milk, fruit/vegetable juice}:  sup = 0.027
# {rolls/buns, fruit/vegetable juice}:  sup = 0.015
# {root vegetables, fruit/vegetable juice}:  sup = 0.012
# {sausage, fruit/vegetable juice}:  sup = 0.01
# {yogurt, fruit/vegetable juice}:  sup = 0.019
# {citrus fruit, fruit/vegetable juice}:  sup = 0.01
# {sugar}:  sup = 0.034
# {whole milk, sugar}:  sup = 0.015
# {other vegetables, sugar}:  sup = 0.011
# {packaged fruit/vegetables}:  sup = 0.013
# {specialty bar}:  sup = 0.027
# {pastry}:  sup = 0.089
# {soda, pastry}:  sup = 0.021
# {whole milk, pastry}:  sup = 0.033
# {yogurt, pastry}:  sup = 0.018
# {root vegetables, pastry}:  sup = 0.011
# {tropical fruit, pastry}:  sup = 0.013
# {rolls/buns, pastry}:  sup = 0.021
# {sausage, pastry}:  sup = 0.013
# {other vegetables, pastry}:  sup = 0.023
# {whole milk, other vegetables, pastry}:  sup = 0.011
# {shopping bags, pastry}:  sup = 0.012
# {butter milk}:  sup = 0.028
# {whole milk, butter milk}:  sup = 0.012
# {other vegetables, butter milk}:  sup = 0.01
# {detergent}:  sup = 0.019
# {processed cheese}:  sup = 0.017
# {root vegetables}:  sup = 0.109
# {other vegetables, root vegetables}:  sup = 0.047
# {whole milk, other vegetables, root vegetables}:  sup = 0.023
# {rolls/buns, root vegetables}:  sup = 0.024
# {other vegetables, rolls/buns, root vegetables}:  sup = 0.012
# {whole milk, rolls/buns, root vegetables}:  sup = 0.013
# {whole milk, root vegetables}:  sup = 0.049
# {soda, root vegetables}:  sup = 0.019
# {yogurt, root vegetables}:  sup = 0.026
# {whole milk, yogurt, root vegetables}:  sup = 0.015
# {other vegetables, yogurt, root vegetables}:  sup = 0.013
# {bottled water, root vegetables}:  sup = 0.016
# {waffles}:  sup = 0.038
# {other vegetables, waffles}:  sup = 0.01
# {whole milk, waffles}:  sup = 0.013
# {salty snack}:  sup = 0.038
# {other vegetables, salty snack}:  sup = 0.011
# {whole milk, salty snack}:  sup = 0.011
# {candy}:  sup = 0.03
# {frozen dessert}:  sup = 0.011
# {canned beer}:  sup = 0.078
# {soda, canned beer}:  sup = 0.014
# {shopping bags, canned beer}:  sup = 0.011
# {rolls/buns, canned beer}:  sup = 0.011
# {sausage}:  sup = 0.094
# {rolls/buns, sausage}:  sup = 0.031
# {soda, sausage}:  sup = 0.024
# {shopping bags, sausage}:  sup = 0.016
# {whole milk, sausage}:  sup = 0.03
# {yogurt, sausage}:  sup = 0.02
# {root vegetables, sausage}:  sup = 0.015
# {other vegetables, sausage}:  sup = 0.027
# {whole milk, other vegetables, sausage}:  sup = 0.01
# {tropical fruit, sausage}:  sup = 0.014
# {bottled water, sausage}:  sup = 0.012
# {shopping bags}:  sup = 0.099
# {soda, shopping bags}:  sup = 0.025
# {rolls/buns, shopping bags}:  sup = 0.02
# {whole milk, shopping bags}:  sup = 0.025
# {yogurt, shopping bags}:  sup = 0.015
# {other vegetables, shopping bags}:  sup = 0.023
# {bottled water, shopping bags}:  sup = 0.011
# {tropical fruit, shopping bags}:  sup = 0.014
# {root vegetables, shopping bags}:  sup = 0.013
# {brown bread}:  sup = 0.065
# {soda, brown bread}:  sup = 0.013
# {whole milk, brown bread}:  sup = 0.025
# {yogurt, brown bread}:  sup = 0.015
# {root vegetables, brown bread}:  sup = 0.01
# {tropical fruit, brown bread}:  sup = 0.011
# {other vegetables, brown bread}:  sup = 0.019
# {rolls/buns, brown bread}:  sup = 0.013
# {sausage, brown bread}:  sup = 0.011
# {beverages}:  sup = 0.026
# {napkins}:  sup = 0.052
# {other vegetables, napkins}:  sup = 0.014
# {rolls/buns, napkins}:  sup = 0.012
# {whole milk, napkins}:  sup = 0.02
# {yogurt, napkins}:  sup = 0.012
# {soda, napkins}:  sup = 0.012
# {tropical fruit, napkins}:  sup = 0.01
# {hamburger meat}:  sup = 0.033
# {other vegetables, hamburger meat}:  sup = 0.014
# {whole milk, hamburger meat}:  sup = 0.015
# {hygiene articles}:  sup = 0.033
# {whole milk, hygiene articles}:  sup = 0.013
# {whipped/sour cream}:  sup = 0.072
# {whole milk, whipped/sour cream}:  sup = 0.032
# {other vegetables, whipped/sour cream}:  sup = 0.029
# {whole milk, other vegetables, whipped/sour cream}:  sup = 0.015
# {soda, whipped/sour cream}:  sup = 0.012
# {rolls/buns, whipped/sour cream}:  sup = 0.015
# {root vegetables, whipped/sour cream}:  sup = 0.017
# {citrus fruit, whipped/sour cream}:  sup = 0.011
# {yogurt, whipped/sour cream}:  sup = 0.021
# {whole milk, yogurt, whipped/sour cream}:  sup = 0.011
# {other vegetables, yogurt, whipped/sour cream}:  sup = 0.01
# {tropical fruit, whipped/sour cream}:  sup = 0.014
# {pork}:  sup = 0.058
# {whole milk, pork}:  sup = 0.022
# {other vegetables, pork}:  sup = 0.022
# {whole milk, other vegetables, pork}:  sup = 0.01
# {soda, pork}:  sup = 0.012
# {rolls/buns, pork}:  sup = 0.011
# {root vegetables, pork}:  sup = 0.014
# {berries}:  sup = 0.033
# {whole milk, berries}:  sup = 0.012
# {other vegetables, berries}:  sup = 0.01
# {yogurt, berries}:  sup = 0.011
# {grapes}:  sup = 0.022
# {dessert}:  sup = 0.037
# {whole milk, dessert}:  sup = 0.014
# {other vegetables, dessert}:  sup = 0.012
# {domestic eggs}:  sup = 0.063
# {whole milk, domestic eggs}:  sup = 0.03
# {soda, domestic eggs}:  sup = 0.012
# {yogurt, domestic eggs}:  sup = 0.014
# {root vegetables, domestic eggs}:  sup = 0.014
# {tropical fruit, domestic eggs}:  sup = 0.011
# {other vegetables, domestic eggs}:  sup = 0.022
# {whole milk, other vegetables, domestic eggs}:  sup = 0.012
# {citrus fruit, domestic eggs}:  sup = 0.01
# {rolls/buns, domestic eggs}:  sup = 0.016
# {spread cheese}:  sup = 0.011
# {misc. beverages}:  sup = 0.028
# {hard cheese}:  sup = 0.025
# {whole milk, hard cheese}:  sup = 0.01
# {cat food}:  sup = 0.023
# {ham}:  sup = 0.026
# {whole milk, ham}:  sup = 0.011
# {baking powder}:  sup = 0.018
# {pickled vegetables}:  sup = 0.018
# {oil}:  sup = 0.028
# {whole milk, oil}:  sup = 0.011
# {chewing gum}:  sup = 0.021
# {ice cream}:  sup = 0.025
# {frozen vegetables}:  sup = 0.048
# {whole milk, frozen vegetables}:  sup = 0.02
# {other vegetables, frozen vegetables}:  sup = 0.018
# {rolls/buns, frozen vegetables}:  sup = 0.01
# {root vegetables, frozen vegetables}:  sup = 0.012
# {yogurt, frozen vegetables}:  sup = 0.012
# {canned fish}:  sup = 0.015
# {seasonal products}:  sup = 0.014
# {red/blush wine}:  sup = 0.019
# {specialty chocolate}:  sup = 0.03
# {flower (seeds)}:  sup = 0.01
# {salt}:  sup = 0.011
# {frozen meals}:  sup = 0.028
# {canned vegetables}:  sup = 0.011
# {onions}:  sup = 0.031
# {whole milk, onions}:  sup = 0.012
# {other vegetables, onions}:  sup = 0.014
# {white wine}:  sup = 0.019
# {herbs}:  sup = 0.016
# {sliced cheese}:  sup = 0.025
# {whole milk, sliced cheese}:  sup = 0.011
# {pasta}:  sup = 0.015
# {cling film/bags}:  sup = 0.011
# {soft cheese}:  sup = 0.017
# {cake bar}:  sup = 0.013
# {frozen fish}:  sup = 0.012
# {dish cleaner}:  sup = 0.01
# {meat}:  sup = 0.026
# {mustard}:  sup = 0.012
# {liquor}:  sup = 0.011
# {roll products}:  sup = 0.01

# %%
#listing association rules derived
Association_fp = generate_rules(Fi_fp, Frequent_items_fp, min_confidence=0.1, verbose=True)
# Out:
# {whole milk} ---> {citrus fruit}:  conf = 0.119, sup = 0.031
# {citrus fruit} ---> {whole milk}:  conf = 0.369, sup = 0.031
# {yogurt} ---> {citrus fruit}:  conf = 0.155, sup = 0.022
# {citrus fruit} ---> {yogurt}:  conf = 0.262, sup = 0.022
# {bottled water} ---> {citrus fruit}:  conf = 0.122, sup = 0.014
# {citrus fruit} ---> {bottled water}:  conf = 0.163, sup = 0.014
# {tropical fruit} ---> {citrus fruit}:  conf = 0.19, sup = 0.02
# {citrus fruit} ---> {tropical fruit}:  conf = 0.241, sup = 0.02
# {other vegetables} ---> {citrus fruit}:  conf = 0.149, sup = 0.029
# {citrus fruit} ---> {other vegetables}:  conf = 0.349, sup = 0.029
# {root vegetables} ---> {citrus fruit}:  conf = 0.162, sup = 0.018
# {citrus fruit} ---> {root vegetables}:  conf = 0.214, sup = 0.018
# {citrus fruit} ---> {sausage}:  conf = 0.136, sup = 0.011
# {sausage} ---> {citrus fruit}:  conf = 0.12, sup = 0.011
# {citrus fruit} ---> {rolls/buns}:  conf = 0.203, sup = 0.017
# {citrus fruit} ---> {soda}:  conf = 0.155, sup = 0.013
# {other vegetables} ---> {margarine}:  conf = 0.102, sup = 0.02
# {margarine} ---> {other vegetables}:  conf = 0.337, sup = 0.02
# {margarine} ---> {whole milk}:  conf = 0.413, sup = 0.024
# {margarine} ---> {rolls/buns}:  conf = 0.252, sup = 0.015
# {root vegetables} ---> {margarine}:  conf = 0.102, sup = 0.011
# {margarine} ---> {root vegetables}:  conf = 0.189, sup = 0.011
# {margarine} ---> {bottled water}:  conf = 0.175, sup = 0.01
# {yogurt} ---> {margarine}:  conf = 0.102, sup = 0.014
# {margarine} ---> {yogurt}:  conf = 0.243, sup = 0.014
# {margarine} ---> {soda}:  conf = 0.174, sup = 0.01
# {yogurt} ---> {whole milk}:  conf = 0.402, sup = 0.056
# {whole milk} ---> {yogurt}:  conf = 0.219, sup = 0.056
# {soda} ---> {yogurt}:  conf = 0.157, sup = 0.027
# {yogurt} ---> {soda}:  conf = 0.196, sup = 0.027
# {rolls/buns} ---> {yogurt}:  conf = 0.187, sup = 0.034
# {yogurt} ---> {rolls/buns}:  conf = 0.246, sup = 0.034
# {yogurt} ---> {other vegetables}:  conf = 0.311, sup = 0.043
# {other vegetables} ---> {yogurt}:  conf = 0.224, sup = 0.043
# {yogurt} ---> {tropical fruit}:  conf = 0.21, sup = 0.029
# {tropical fruit} ---> {yogurt}:  conf = 0.279, sup = 0.029
# {other vegetables} ---> {tropical fruit}:  conf = 0.185, sup = 0.036
# {tropical fruit} ---> {other vegetables}:  conf = 0.342, sup = 0.036
# {bottled water} ---> {tropical fruit}:  conf = 0.167, sup = 0.019
# {tropical fruit} ---> {bottled water}:  conf = 0.176, sup = 0.019
# {tropical fruit} ---> {whole milk}:  conf = 0.403, sup = 0.042
# {whole milk} ---> {tropical fruit}:  conf = 0.166, sup = 0.042
# {rolls/buns} ---> {tropical fruit}:  conf = 0.134, sup = 0.025
# {tropical fruit} ---> {rolls/buns}:  conf = 0.234, sup = 0.025
# {root vegetables} ---> {tropical fruit}:  conf = 0.193, sup = 0.021
# {tropical fruit} ---> {root vegetables}:  conf = 0.201, sup = 0.021
# {soda} ---> {tropical fruit}:  conf = 0.12, sup = 0.021
# {tropical fruit} ---> {soda}:  conf = 0.199, sup = 0.021
# {coffee} ---> {whole milk}:  conf = 0.322, sup = 0.019
# {coffee} ---> {other vegetables}:  conf = 0.231, sup = 0.013
# {coffee} ---> {rolls/buns}:  conf = 0.189, sup = 0.011
# {yogurt} ---> {pip fruit}:  conf = 0.129, sup = 0.018
# {pip fruit} ---> {yogurt}:  conf = 0.238, sup = 0.018
# {pip fruit} ---> {whole milk}:  conf = 0.398, sup = 0.03
# {whole milk} ---> {pip fruit}:  conf = 0.118, sup = 0.03
# {pip fruit} ---> {rolls/buns}:  conf = 0.184, sup = 0.014
# {pip fruit} ---> {tropical fruit}:  conf = 0.27, sup = 0.02
# {tropical fruit} ---> {pip fruit}:  conf = 0.195, sup = 0.02
# {pip fruit} ---> {sausage}:  conf = 0.142, sup = 0.011
# {sausage} ---> {pip fruit}:  conf = 0.115, sup = 0.011
# {pip fruit} ---> {citrus fruit}:  conf = 0.183, sup = 0.014
# {citrus fruit} ---> {pip fruit}:  conf = 0.167, sup = 0.014
# {pip fruit} ---> {other vegetables}:  conf = 0.345, sup = 0.026
# {other vegetables} ---> {pip fruit}:  conf = 0.135, sup = 0.026
# {root vegetables} ---> {pip fruit}:  conf = 0.143, sup = 0.016
# {pip fruit} ---> {root vegetables}:  conf = 0.206, sup = 0.016
# {pip fruit} ---> {bottled water}:  conf = 0.14, sup = 0.011
# {pip fruit} ---> {soda}:  conf = 0.176, sup = 0.013
# {pip fruit} ---> {pastry}:  conf = 0.141, sup = 0.011
# {pastry} ---> {pip fruit}:  conf = 0.12, sup = 0.011
# {cream cheese} ---> {yogurt}:  conf = 0.313, sup = 0.012
# {cream cheese} ---> {whole milk}:  conf = 0.415, sup = 0.016
# {cream cheese} ---> {other vegetables}:  conf = 0.346, sup = 0.014
# {other vegetables} ---> {whole milk}:  conf = 0.387, sup = 0.075
# {whole milk} ---> {other vegetables}:  conf = 0.293, sup = 0.075
# {long life bakery product} ---> {whole milk}:  conf = 0.361, sup = 0.014
# {long life bakery product} ---> {other vegetables}:  conf = 0.285, sup = 0.011
# {whole milk} ---> {butter}:  conf = 0.108, sup = 0.028
# {butter} ---> {whole milk}:  conf = 0.497, sup = 0.028
# {yogurt} ---> {butter}:  conf = 0.105, sup = 0.015
# {butter} ---> {yogurt}:  conf = 0.264, sup = 0.015
# {other vegetables} ---> {butter}:  conf = 0.104, sup = 0.02
# {butter} ---> {other vegetables}:  conf = 0.361, sup = 0.02
# {butter} ---> {rolls/buns}:  conf = 0.242, sup = 0.013
# {root vegetables} ---> {butter}:  conf = 0.118, sup = 0.013
# {butter} ---> {root vegetables}:  conf = 0.233, sup = 0.013
# {whipped/sour cream} ---> {butter}:  conf = 0.142, sup = 0.01
# {butter} ---> {whipped/sour cream}:  conf = 0.183, sup = 0.01
# {rolls/buns} ---> {other vegetables}:  conf = 0.232, sup = 0.043
# {other vegetables} ---> {rolls/buns}:  conf = 0.22, sup = 0.043
# {rolls/buns} ---> {whole milk}:  conf = 0.308, sup = 0.057
# {whole milk} ---> {rolls/buns}:  conf = 0.222, sup = 0.057
# {bottled beer} ---> {other vegetables}:  conf = 0.201, sup = 0.016
# {bottled beer} ---> {rolls/buns}:  conf = 0.169, sup = 0.014
# {bottled water} ---> {bottled beer}:  conf = 0.143, sup = 0.016
# {bottled beer} ---> {bottled water}:  conf = 0.196, sup = 0.016
# {bottled beer} ---> {soda}:  conf = 0.211, sup = 0.017
# {bottled beer} ---> {whole milk}:  conf = 0.254, sup = 0.02
# {other vegetables} ---> {bottled water}:  conf = 0.128, sup = 0.025
# {bottled water} ---> {other vegetables}:  conf = 0.224, sup = 0.025
# {bottled water} ---> {whole milk}:  conf = 0.311, sup = 0.034
# {whole milk} ---> {bottled water}:  conf = 0.135, sup = 0.034
# {yogurt} ---> {bottled water}:  conf = 0.165, sup = 0.023
# {bottled water} ---> {yogurt}:  conf = 0.208, sup = 0.023
# {rolls/buns} ---> {bottled water}:  conf = 0.132, sup = 0.024
# {bottled water} ---> {rolls/buns}:  conf = 0.219, sup = 0.024
# {soda} ---> {bottled water}:  conf = 0.166, sup = 0.029
# {bottled water} ---> {soda}:  conf = 0.262, sup = 0.029
# {chocolate} ---> {other vegetables}:  conf = 0.256, sup = 0.013
# {chocolate} ---> {rolls/buns}:  conf = 0.238, sup = 0.012
# {chocolate} ---> {soda}:  conf = 0.273, sup = 0.014
# {chocolate} ---> {whole milk}:  conf = 0.336, sup = 0.017
# {white bread} ---> {other vegetables}:  conf = 0.326, sup = 0.014
# {white bread} ---> {whole milk}:  conf = 0.406, sup = 0.017
# {white bread} ---> {soda}:  conf = 0.244, sup = 0.01
# {curd} ---> {whole milk}:  conf = 0.49, sup = 0.026
# {whole milk} ---> {curd}:  conf = 0.102, sup = 0.026
# {yogurt} ---> {curd}:  conf = 0.124, sup = 0.017
# {curd} ---> {yogurt}:  conf = 0.324, sup = 0.017
# {curd} ---> {tropical fruit}:  conf = 0.193, sup = 0.01
# {curd} ---> {other vegetables}:  conf = 0.323, sup = 0.017
# {curd} ---> {rolls/buns}:  conf = 0.189, sup = 0.01
# {curd} ---> {root vegetables}:  conf = 0.204, sup = 0.011
# {curd} ---> {whipped/sour cream}:  conf = 0.197, sup = 0.01
# {whipped/sour cream} ---> {curd}:  conf = 0.146, sup = 0.01
# {beef} ---> {rolls/buns}:  conf = 0.26, sup = 0.014
# {beef} ---> {whole milk}:  conf = 0.405, sup = 0.021
# {root vegetables} ---> {beef}:  conf = 0.16, sup = 0.017
# {beef} ---> {root vegetables}:  conf = 0.331, sup = 0.017
# {beef} ---> {other vegetables}:  conf = 0.376, sup = 0.02
# {other vegetables} ---> {beef}:  conf = 0.102, sup = 0.02
# {beef} ---> {yogurt}:  conf = 0.223, sup = 0.012
# {rolls/buns} ---> {soda}:  conf = 0.208, sup = 0.038
# {soda} ---> {rolls/buns}:  conf = 0.22, sup = 0.038
# {soda} ---> {whole milk}:  conf = 0.23, sup = 0.04
# {whole milk} ---> {soda}:  conf = 0.157, sup = 0.04
# {soda} ---> {other vegetables}:  conf = 0.188, sup = 0.033
# {other vegetables} ---> {soda}:  conf = 0.169, sup = 0.033
# {rolls/buns} ---> {frankfurter}:  conf = 0.104, sup = 0.019
# {frankfurter} ---> {rolls/buns}:  conf = 0.326, sup = 0.019
# {frankfurter} ---> {soda}:  conf = 0.191, sup = 0.011
# {frankfurter} ---> {whole milk}:  conf = 0.348, sup = 0.021
# {frankfurter} ---> {other vegetables}:  conf = 0.279, sup = 0.016
# {frankfurter} ---> {root vegetables}:  conf = 0.172, sup = 0.01
# {frankfurter} ---> {sausage}:  conf = 0.171, sup = 0.01
# {sausage} ---> {frankfurter}:  conf = 0.107, sup = 0.01
# {frankfurter} ---> {yogurt}:  conf = 0.19, sup = 0.011
# {chicken} ---> {other vegetables}:  conf = 0.417, sup = 0.018
# {chicken} ---> {root vegetables}:  conf = 0.254, sup = 0.011
# {chicken} ---> {whole milk}:  conf = 0.41, sup = 0.018
# {newspapers} ---> {tropical fruit}:  conf = 0.148, sup = 0.012
# {tropical fruit} ---> {newspapers}:  conf = 0.112, sup = 0.012
# {newspapers} ---> {soda}:  conf = 0.183, sup = 0.015
# {rolls/buns} ---> {newspapers}:  conf = 0.107, sup = 0.02
# {newspapers} ---> {rolls/buns}:  conf = 0.247, sup = 0.02
# {yogurt} ---> {newspapers}:  conf = 0.11, sup = 0.015
# {newspapers} ---> {yogurt}:  conf = 0.192, sup = 0.015
# {newspapers} ---> {bottled water}:  conf = 0.141, sup = 0.011
# {bottled water} ---> {newspapers}:  conf = 0.102, sup = 0.011
# {newspapers} ---> {whole milk}:  conf = 0.343, sup = 0.027
# {whole milk} ---> {newspapers}:  conf = 0.107, sup = 0.027
# {newspapers} ---> {other vegetables}:  conf = 0.242, sup = 0.019
# {root vegetables} ---> {newspapers}:  conf = 0.105, sup = 0.011
# {newspapers} ---> {root vegetables}:  conf = 0.144, sup = 0.011
# {soda} ---> {fruit/vegetable juice}:  conf = 0.106, sup = 0.018
# {fruit/vegetable juice} ---> {soda}:  conf = 0.255, sup = 0.018
# {shopping bags} ---> {fruit/vegetable juice}:  conf = 0.108, sup = 0.011
# {fruit/vegetable juice} ---> {shopping bags}:  conf = 0.148, sup = 0.011
# {fruit/vegetable juice} ---> {other vegetables}:  conf = 0.291, sup = 0.021
# {other vegetables} ---> {fruit/vegetable juice}:  conf = 0.109, sup = 0.021
# {fruit/vegetable juice} ---> {tropical fruit}:  conf = 0.19, sup = 0.014
# {tropical fruit} ---> {fruit/vegetable juice}:  conf = 0.131, sup = 0.014
# {fruit/vegetable juice} ---> {bottled water}:  conf = 0.197, sup = 0.014
# {bottled water} ---> {fruit/vegetable juice}:  conf = 0.129, sup = 0.014
# {fruit/vegetable juice} ---> {whole milk}:  conf = 0.368, sup = 0.027
# {whole milk} ---> {fruit/vegetable juice}:  conf = 0.104, sup = 0.027
# {fruit/vegetable juice} ---> {rolls/buns}:  conf = 0.201, sup = 0.015
# {root vegetables} ---> {fruit/vegetable juice}:  conf = 0.11, sup = 0.012
# {fruit/vegetable juice} ---> {root vegetables}:  conf = 0.166, sup = 0.012
# {fruit/vegetable juice} ---> {sausage}:  conf = 0.139, sup = 0.01
# {sausage} ---> {fruit/vegetable juice}:  conf = 0.107, sup = 0.01
# {yogurt} ---> {fruit/vegetable juice}:  conf = 0.134, sup = 0.019
# {fruit/vegetable juice} ---> {yogurt}:  conf = 0.259, sup = 0.019
# {fruit/vegetable juice} ---> {citrus fruit}:  conf = 0.143, sup = 0.01
# {citrus fruit} ---> {fruit/vegetable juice}:  conf = 0.125, sup = 0.01
# {sugar} ---> {whole milk}:  conf = 0.444, sup = 0.015
# {sugar} ---> {other vegetables}:  conf = 0.318, sup = 0.011
# {soda} ---> {pastry}:  conf = 0.121, sup = 0.021
# {pastry} ---> {soda}:  conf = 0.237, sup = 0.021
# {pastry} ---> {whole milk}:  conf = 0.374, sup = 0.033
# {whole milk} ---> {pastry}:  conf = 0.13, sup = 0.033
# {yogurt} ---> {pastry}:  conf = 0.127, sup = 0.018
# {pastry} ---> {yogurt}:  conf = 0.199, sup = 0.018
# {root vegetables} ---> {pastry}:  conf = 0.101, sup = 0.011
# {pastry} ---> {root vegetables}:  conf = 0.123, sup = 0.011
# {tropical fruit} ---> {pastry}:  conf = 0.126, sup = 0.013
# {pastry} ---> {tropical fruit}:  conf = 0.149, sup = 0.013
# {rolls/buns} ---> {pastry}:  conf = 0.114, sup = 0.021
# {pastry} ---> {rolls/buns}:  conf = 0.235, sup = 0.021
# {pastry} ---> {sausage}:  conf = 0.141, sup = 0.013
# {sausage} ---> {pastry}:  conf = 0.133, sup = 0.013
# {other vegetables} ---> {pastry}:  conf = 0.117, sup = 0.023
# {pastry} ---> {other vegetables}:  conf = 0.254, sup = 0.023
# {shopping bags} ---> {pastry}:  conf = 0.121, sup = 0.012
# {pastry} ---> {shopping bags}:  conf = 0.134, sup = 0.012
# {butter milk} ---> {whole milk}:  conf = 0.415, sup = 0.012
# {butter milk} ---> {other vegetables}:  conf = 0.371, sup = 0.01
# {root vegetables} ---> {other vegetables}:  conf = 0.435, sup = 0.047
# {other vegetables} ---> {root vegetables}:  conf = 0.245, sup = 0.047
# {rolls/buns} ---> {root vegetables}:  conf = 0.132, sup = 0.024
# {root vegetables} ---> {rolls/buns}:  conf = 0.223, sup = 0.024
# {root vegetables} ---> {whole milk}:  conf = 0.449, sup = 0.049
# {whole milk} ---> {root vegetables}:  conf = 0.191, sup = 0.049
# {soda} ---> {root vegetables}:  conf = 0.107, sup = 0.019
# {root vegetables} ---> {soda}:  conf = 0.171, sup = 0.019
# {yogurt} ---> {root vegetables}:  conf = 0.185, sup = 0.026
# {root vegetables} ---> {yogurt}:  conf = 0.237, sup = 0.026
# {root vegetables} ---> {bottled water}:  conf = 0.144, sup = 0.016
# {bottled water} ---> {root vegetables}:  conf = 0.142, sup = 0.016
# {waffles} ---> {other vegetables}:  conf = 0.262, sup = 0.01
# {waffles} ---> {whole milk}:  conf = 0.331, sup = 0.013
# {salty snack} ---> {other vegetables}:  conf = 0.285, sup = 0.011
# {salty snack} ---> {whole milk}:  conf = 0.296, sup = 0.011
# {canned beer} ---> {soda}:  conf = 0.178, sup = 0.014
# {shopping bags} ---> {canned beer}:  conf = 0.116, sup = 0.011
# {canned beer} ---> {shopping bags}:  conf = 0.147, sup = 0.011
# {canned beer} ---> {rolls/buns}:  conf = 0.145, sup = 0.011
# {rolls/buns} ---> {sausage}:  conf = 0.166, sup = 0.031
# {sausage} ---> {rolls/buns}:  conf = 0.326, sup = 0.031
# {soda} ---> {sausage}:  conf = 0.139, sup = 0.024
# {sausage} ---> {soda}:  conf = 0.259, sup = 0.024
# {shopping bags} ---> {sausage}:  conf = 0.159, sup = 0.016
# {sausage} ---> {shopping bags}:  conf = 0.167, sup = 0.016
# {whole milk} ---> {sausage}:  conf = 0.117, sup = 0.03
# {sausage} ---> {whole milk}:  conf = 0.318, sup = 0.03
# {yogurt} ---> {sausage}:  conf = 0.141, sup = 0.02
# {sausage} ---> {yogurt}:  conf = 0.209, sup = 0.02
# {root vegetables} ---> {sausage}:  conf = 0.137, sup = 0.015
# {sausage} ---> {root vegetables}:  conf = 0.159, sup = 0.015
# {other vegetables} ---> {sausage}:  conf = 0.139, sup = 0.027
# {sausage} ---> {other vegetables}:  conf = 0.287, sup = 0.027
# {tropical fruit} ---> {sausage}:  conf = 0.133, sup = 0.014
# {sausage} ---> {tropical fruit}:  conf = 0.148, sup = 0.014
# {bottled water} ---> {sausage}:  conf = 0.109, sup = 0.012
# {sausage} ---> {bottled water}:  conf = 0.128, sup = 0.012
# {soda} ---> {shopping bags}:  conf = 0.141, sup = 0.025
# {shopping bags} ---> {soda}:  conf = 0.25, sup = 0.025
# {rolls/buns} ---> {shopping bags}:  conf = 0.106, sup = 0.02
# {shopping bags} ---> {rolls/buns}:  conf = 0.198, sup = 0.02
# {shopping bags} ---> {whole milk}:  conf = 0.249, sup = 0.025
# {yogurt} ---> {shopping bags}:  conf = 0.109, sup = 0.015
# {shopping bags} ---> {yogurt}:  conf = 0.155, sup = 0.015
# {shopping bags} ---> {other vegetables}:  conf = 0.235, sup = 0.023
# {other vegetables} ---> {shopping bags}:  conf = 0.12, sup = 0.023
# {shopping bags} ---> {bottled water}:  conf = 0.111, sup = 0.011
# {shopping bags} ---> {tropical fruit}:  conf = 0.137, sup = 0.014
# {tropical fruit} ---> {shopping bags}:  conf = 0.129, sup = 0.014
# {root vegetables} ---> {shopping bags}:  conf = 0.118, sup = 0.013
# {shopping bags} ---> {root vegetables}:  conf = 0.13, sup = 0.013
# {brown bread} ---> {soda}:  conf = 0.194, sup = 0.013
# {brown bread} ---> {whole milk}:  conf = 0.389, sup = 0.025
# {yogurt} ---> {brown bread}:  conf = 0.104, sup = 0.015
# {brown bread} ---> {yogurt}:  conf = 0.224, sup = 0.015
# {brown bread} ---> {root vegetables}:  conf = 0.157, sup = 0.01
# {tropical fruit} ---> {brown bread}:  conf = 0.102, sup = 0.011
# {brown bread} ---> {tropical fruit}:  conf = 0.165, sup = 0.011
# {brown bread} ---> {other vegetables}:  conf = 0.288, sup = 0.019
# {brown bread} ---> {rolls/buns}:  conf = 0.194, sup = 0.013
# {sausage} ---> {brown bread}:  conf = 0.114, sup = 0.011
# {brown bread} ---> {sausage}:  conf = 0.165, sup = 0.011
# {napkins} ---> {other vegetables}:  conf = 0.276, sup = 0.014
# {napkins} ---> {rolls/buns}:  conf = 0.223, sup = 0.012
# {napkins} ---> {whole milk}:  conf = 0.377, sup = 0.02
# {napkins} ---> {yogurt}:  conf = 0.235, sup = 0.012
# {napkins} ---> {soda}:  conf = 0.229, sup = 0.012
# {napkins} ---> {tropical fruit}:  conf = 0.192, sup = 0.01
# {hamburger meat} ---> {other vegetables}:  conf = 0.416, sup = 0.014
# {hamburger meat} ---> {whole milk}:  conf = 0.443, sup = 0.015
# {hygiene articles} ---> {whole milk}:  conf = 0.389, sup = 0.013
# {whipped/sour cream} ---> {whole milk}:  conf = 0.45, sup = 0.032
# {whole milk} ---> {whipped/sour cream}:  conf = 0.126, sup = 0.032
# {other vegetables} ---> {whipped/sour cream}:  conf = 0.149, sup = 0.029
# {whipped/sour cream} ---> {other vegetables}:  conf = 0.403, sup = 0.029
# {whipped/sour cream} ---> {soda}:  conf = 0.162, sup = 0.012
# {whipped/sour cream} ---> {rolls/buns}:  conf = 0.204, sup = 0.015
# {root vegetables} ---> {whipped/sour cream}:  conf = 0.157, sup = 0.017
# {whipped/sour cream} ---> {root vegetables}:  conf = 0.238, sup = 0.017
# {whipped/sour cream} ---> {citrus fruit}:  conf = 0.152, sup = 0.011
# {citrus fruit} ---> {whipped/sour cream}:  conf = 0.131, sup = 0.011
# {yogurt} ---> {whipped/sour cream}:  conf = 0.149, sup = 0.021
# {whipped/sour cream} ---> {yogurt}:  conf = 0.289, sup = 0.021
# {tropical fruit} ---> {whipped/sour cream}:  conf = 0.132, sup = 0.014
# {whipped/sour cream} ---> {tropical fruit}:  conf = 0.193, sup = 0.014
# {pork} ---> {whole milk}:  conf = 0.384, sup = 0.022
# {other vegetables} ---> {pork}:  conf = 0.112, sup = 0.022
# {pork} ---> {other vegetables}:  conf = 0.376, sup = 0.022
# {pork} ---> {soda}:  conf = 0.206, sup = 0.012
# {pork} ---> {rolls/buns}:  conf = 0.196, sup = 0.011
# {root vegetables} ---> {pork}:  conf = 0.125, sup = 0.014
# {pork} ---> {root vegetables}:  conf = 0.236, sup = 0.014
# {berries} ---> {whole milk}:  conf = 0.355, sup = 0.012
# {berries} ---> {other vegetables}:  conf = 0.309, sup = 0.01
# {berries} ---> {yogurt}:  conf = 0.318, sup = 0.011
# {dessert} ---> {whole milk}:  conf = 0.37, sup = 0.014
# {dessert} ---> {other vegetables}:  conf = 0.312, sup = 0.012
# {whole milk} ---> {domestic eggs}:  conf = 0.117, sup = 0.03
# {domestic eggs} ---> {whole milk}:  conf = 0.473, sup = 0.03
# {domestic eggs} ---> {soda}:  conf = 0.196, sup = 0.012
# {yogurt} ---> {domestic eggs}:  conf = 0.103, sup = 0.014
# {domestic eggs} ---> {yogurt}:  conf = 0.226, sup = 0.014
# {root vegetables} ---> {domestic eggs}:  conf = 0.132, sup = 0.014
# {domestic eggs} ---> {root vegetables}:  conf = 0.226, sup = 0.014
# {tropical fruit} ---> {domestic eggs}:  conf = 0.109, sup = 0.011
# {domestic eggs} ---> {tropical fruit}:  conf = 0.179, sup = 0.011
# {other vegetables} ---> {domestic eggs}:  conf = 0.115, sup = 0.022
# {domestic eggs} ---> {other vegetables}:  conf = 0.351, sup = 0.022
# {domestic eggs} ---> {citrus fruit}:  conf = 0.163, sup = 0.01
# {citrus fruit} ---> {domestic eggs}:  conf = 0.125, sup = 0.01
# {domestic eggs} ---> {rolls/buns}:  conf = 0.247, sup = 0.016
# {hard cheese} ---> {whole milk}:  conf = 0.411, sup = 0.01
# {ham} ---> {whole milk}:  conf = 0.441, sup = 0.011
# {oil} ---> {whole milk}:  conf = 0.402, sup = 0.011
# {frozen vegetables} ---> {whole milk}:  conf = 0.425, sup = 0.02
# {frozen vegetables} ---> {other vegetables}:  conf = 0.37, sup = 0.018
# {frozen vegetables} ---> {rolls/buns}:  conf = 0.211, sup = 0.01
# {root vegetables} ---> {frozen vegetables}:  conf = 0.106, sup = 0.012
# {frozen vegetables} ---> {root vegetables}:  conf = 0.241, sup = 0.012
# {frozen vegetables} ---> {yogurt}:  conf = 0.258, sup = 0.012
# {onions} ---> {whole milk}:  conf = 0.39, sup = 0.012
# {onions} ---> {other vegetables}:  conf = 0.459, sup = 0.014
# {sliced cheese} ---> {whole milk}:  conf = 0.44, sup = 0.011
# {whole milk, yogurt} ---> {citrus fruit}:  conf = 0.183, sup = 0.01
# {citrus fruit, yogurt} ---> {whole milk}:  conf = 0.474, sup = 0.01
# {citrus fruit, whole milk} ---> {yogurt}:  conf = 0.337, sup = 0.01
# {citrus fruit} ---> {whole milk, yogurt}:  conf = 0.124, sup = 0.01
# {whole milk, other vegetables} ---> {citrus fruit}:  conf = 0.174, sup = 0.013
# {citrus fruit, other vegetables} ---> {whole milk}:  conf = 0.451, sup = 0.013
# {citrus fruit, whole milk} ---> {other vegetables}:  conf = 0.427, sup = 0.013
# {citrus fruit} ---> {whole milk, other vegetables}:  conf = 0.157, sup = 0.013
# {other vegetables, root vegetables} ---> {citrus fruit}:  conf = 0.219, sup = 0.01
# {citrus fruit, root vegetables} ---> {other vegetables}:  conf = 0.586, sup = 0.01
# {citrus fruit, other vegetables} ---> {root vegetables}:  conf = 0.359, sup = 0.01
# {citrus fruit} ---> {other vegetables, root vegetables}:  conf = 0.125, sup = 0.01
# {soda, yogurt} ---> {whole milk}:  conf = 0.383, sup = 0.01
# {whole milk, soda} ---> {yogurt}:  conf = 0.261, sup = 0.01
# {whole milk, yogurt} ---> {soda}:  conf = 0.187, sup = 0.01
# {rolls/buns, yogurt} ---> {whole milk}:  conf = 0.453, sup = 0.016
# {whole milk, rolls/buns} ---> {yogurt}:  conf = 0.275, sup = 0.016
# {whole milk, yogurt} ---> {rolls/buns}:  conf = 0.278, sup = 0.016
# {yogurt} ---> {whole milk, rolls/buns}:  conf = 0.112, sup = 0.016
# {other vegetables, rolls/buns} ---> {yogurt}:  conf = 0.27, sup = 0.011
# {rolls/buns, yogurt} ---> {other vegetables}:  conf = 0.334, sup = 0.011
# {other vegetables, yogurt} ---> {rolls/buns}:  conf = 0.265, sup = 0.011
# {other vegetables, yogurt} ---> {whole milk}:  conf = 0.513, sup = 0.022
# {whole milk, yogurt} ---> {other vegetables}:  conf = 0.397, sup = 0.022
# {whole milk, other vegetables} ---> {yogurt}:  conf = 0.298, sup = 0.022
# {yogurt} ---> {whole milk, other vegetables}:  conf = 0.16, sup = 0.022
# {other vegetables} ---> {whole milk, yogurt}:  conf = 0.115, sup = 0.022
# {tropical fruit, yogurt} ---> {whole milk}:  conf = 0.517, sup = 0.015
# {whole milk, yogurt} ---> {tropical fruit}:  conf = 0.27, sup = 0.015
# {whole milk, tropical fruit} ---> {yogurt}:  conf = 0.358, sup = 0.015
# {yogurt} ---> {whole milk, tropical fruit}:  conf = 0.109, sup = 0.015
# {tropical fruit} ---> {whole milk, yogurt}:  conf = 0.144, sup = 0.015
# {other vegetables, yogurt} ---> {tropical fruit}:  conf = 0.283, sup = 0.012
# {tropical fruit, yogurt} ---> {other vegetables}:  conf = 0.42, sup = 0.012
# {other vegetables, tropical fruit} ---> {yogurt}:  conf = 0.343, sup = 0.012
# {tropical fruit} ---> {other vegetables, yogurt}:  conf = 0.117, sup = 0.012
# {other vegetables, tropical fruit} ---> {whole milk}:  conf = 0.476, sup = 0.017
# {whole milk, other vegetables} ---> {tropical fruit}:  conf = 0.228, sup = 0.017
# {whole milk, tropical fruit} ---> {other vegetables}:  conf = 0.404, sup = 0.017
# {tropical fruit} ---> {whole milk, other vegetables}:  conf = 0.163, sup = 0.017
# {tropical fruit, rolls/buns} ---> {whole milk}:  conf = 0.446, sup = 0.011
# {whole milk, rolls/buns} ---> {tropical fruit}:  conf = 0.194, sup = 0.011
# {whole milk, tropical fruit} ---> {rolls/buns}:  conf = 0.26, sup = 0.011
# {tropical fruit} ---> {whole milk, rolls/buns}:  conf = 0.105, sup = 0.011
# {other vegetables, root vegetables} ---> {tropical fruit}:  conf = 0.26, sup = 0.012
# {tropical fruit, root vegetables} ---> {other vegetables}:  conf = 0.585, sup = 0.012
# {other vegetables, tropical fruit} ---> {root vegetables}:  conf = 0.343, sup = 0.012
# {root vegetables} ---> {other vegetables, tropical fruit}:  conf = 0.113, sup = 0.012
# {tropical fruit} ---> {other vegetables, root vegetables}:  conf = 0.117, sup = 0.012
# {tropical fruit, root vegetables} ---> {whole milk}:  conf = 0.57, sup = 0.012
# {whole milk, root vegetables} ---> {tropical fruit}:  conf = 0.245, sup = 0.012
# {whole milk, tropical fruit} ---> {root vegetables}:  conf = 0.284, sup = 0.012
# {root vegetables} ---> {whole milk, tropical fruit}:  conf = 0.11, sup = 0.012
# {tropical fruit} ---> {whole milk, root vegetables}:  conf = 0.114, sup = 0.012
# {other vegetables, pip fruit} ---> {whole milk}:  conf = 0.518, sup = 0.014
# {whole milk, pip fruit} ---> {other vegetables}:  conf = 0.449, sup = 0.014
# {whole milk, other vegetables} ---> {pip fruit}:  conf = 0.181, sup = 0.014
# {pip fruit} ---> {whole milk, other vegetables}:  conf = 0.179, sup = 0.014
# {whole milk, other vegetables} ---> {butter}:  conf = 0.154, sup = 0.011
# {butter, other vegetables} ---> {whole milk}:  conf = 0.574, sup = 0.011
# {butter, whole milk} ---> {other vegetables}:  conf = 0.417, sup = 0.011
# {butter} ---> {whole milk, other vegetables}:  conf = 0.207, sup = 0.011
# {other vegetables, rolls/buns} ---> {whole milk}:  conf = 0.42, sup = 0.018
# {whole milk, rolls/buns} ---> {other vegetables}:  conf = 0.316, sup = 0.018
# {whole milk, other vegetables} ---> {rolls/buns}:  conf = 0.239, sup = 0.018
# {whole milk, other vegetables} ---> {bottled water}:  conf = 0.144, sup = 0.011
# {other vegetables, bottled water} ---> {whole milk}:  conf = 0.434, sup = 0.011
# {whole milk, bottled water} ---> {other vegetables}:  conf = 0.314, sup = 0.011
# {whole milk, yogurt} ---> {curd}:  conf = 0.18, sup = 0.01
# {yogurt, curd} ---> {whole milk}:  conf = 0.582, sup = 0.01
# {whole milk, curd} ---> {yogurt}:  conf = 0.385, sup = 0.01
# {curd} ---> {whole milk, yogurt}:  conf = 0.189, sup = 0.01
# {other vegetables, soda} ---> {whole milk}:  conf = 0.425, sup = 0.014
# {whole milk, soda} ---> {other vegetables}:  conf = 0.348, sup = 0.014
# {whole milk, other vegetables} ---> {soda}:  conf = 0.186, sup = 0.014
# {other vegetables, fruit/vegetable juice} ---> {whole milk}:  conf = 0.498, sup = 0.01
# {whole milk, fruit/vegetable juice} ---> {other vegetables}:  conf = 0.393, sup = 0.01
# {whole milk, other vegetables} ---> {fruit/vegetable juice}:  conf = 0.14, sup = 0.01
# {fruit/vegetable juice} ---> {whole milk, other vegetables}:  conf = 0.145, sup = 0.01
# {other vegetables, pastry} ---> {whole milk}:  conf = 0.468, sup = 0.011
# {whole milk, other vegetables} ---> {pastry}:  conf = 0.141, sup = 0.011
# {whole milk, pastry} ---> {other vegetables}:  conf = 0.318, sup = 0.011
# {pastry} ---> {whole milk, other vegetables}:  conf = 0.119, sup = 0.011
# {other vegetables, root vegetables} ---> {whole milk}:  conf = 0.489, sup = 0.023
# {whole milk, root vegetables} ---> {other vegetables}:  conf = 0.474, sup = 0.023
# {whole milk, other vegetables} ---> {root vegetables}:  conf = 0.31, sup = 0.023
# {root vegetables} ---> {whole milk, other vegetables}:  conf = 0.213, sup = 0.023
# {other vegetables} ---> {whole milk, root vegetables}:  conf = 0.12, sup = 0.023
# {other vegetables, rolls/buns} ---> {root vegetables}:  conf = 0.286, sup = 0.012
# {rolls/buns, root vegetables} ---> {other vegetables}:  conf = 0.502, sup = 0.012
# {other vegetables, root vegetables} ---> {rolls/buns}:  conf = 0.258, sup = 0.012
# {root vegetables} ---> {other vegetables, rolls/buns}:  conf = 0.112, sup = 0.012
# {rolls/buns, root vegetables} ---> {whole milk}:  conf = 0.523, sup = 0.013
# {whole milk, rolls/buns} ---> {root vegetables}:  conf = 0.224, sup = 0.013
# {whole milk, root vegetables} ---> {rolls/buns}:  conf = 0.26, sup = 0.013
# {root vegetables} ---> {whole milk, rolls/buns}:  conf = 0.117, sup = 0.013
# {yogurt, root vegetables} ---> {whole milk}:  conf = 0.563, sup = 0.015
# {whole milk, yogurt} ---> {root vegetables}:  conf = 0.26, sup = 0.015
# {whole milk, root vegetables} ---> {yogurt}:  conf = 0.297, sup = 0.015
# {yogurt} ---> {whole milk, root vegetables}:  conf = 0.104, sup = 0.015
# {root vegetables} ---> {whole milk, yogurt}:  conf = 0.133, sup = 0.015
# {other vegetables, yogurt} ---> {root vegetables}:  conf = 0.297, sup = 0.013
# {yogurt, root vegetables} ---> {other vegetables}:  conf = 0.5, sup = 0.013
# {other vegetables, root vegetables} ---> {yogurt}:  conf = 0.273, sup = 0.013
# {root vegetables} ---> {other vegetables, yogurt}:  conf = 0.118, sup = 0.013
# {whole milk, other vegetables} ---> {sausage}:  conf = 0.136, sup = 0.01
# {sausage, other vegetables} ---> {whole milk}:  conf = 0.377, sup = 0.01
# {sausage, whole milk} ---> {other vegetables}:  conf = 0.34, sup = 0.01
# {sausage} ---> {whole milk, other vegetables}:  conf = 0.108, sup = 0.01
# {whipped/sour cream, other vegetables} ---> {whole milk}:  conf = 0.507, sup = 0.015
# {whole milk, other vegetables} ---> {whipped/sour cream}:  conf = 0.196, sup = 0.015
# {whole milk, whipped/sour cream} ---> {other vegetables}:  conf = 0.454, sup = 0.015
# {whipped/sour cream} ---> {whole milk, other vegetables}:  conf = 0.204, sup = 0.015
# {whipped/sour cream, yogurt} ---> {whole milk}:  conf = 0.525, sup = 0.011
# {whole milk, yogurt} ---> {whipped/sour cream}:  conf = 0.194, sup = 0.011
# {whole milk, whipped/sour cream} ---> {yogurt}:  conf = 0.338, sup = 0.011
# {whipped/sour cream} ---> {whole milk, yogurt}:  conf = 0.152, sup = 0.011
# {other vegetables, yogurt} ---> {whipped/sour cream}:  conf = 0.234, sup = 0.01
# {whipped/sour cream, yogurt} ---> {other vegetables}:  conf = 0.49, sup = 0.01
# {whipped/sour cream, other vegetables} ---> {yogurt}:  conf = 0.352, sup = 0.01
# {whipped/sour cream} ---> {other vegetables, yogurt}:  conf = 0.142, sup = 0.01
# {pork, other vegetables} ---> {whole milk}:  conf = 0.469, sup = 0.01
# {whole milk, other vegetables} ---> {pork}:  conf = 0.136, sup = 0.01
# {whole milk, pork} ---> {other vegetables}:  conf = 0.459, sup = 0.01
# {pork} ---> {whole milk, other vegetables}:  conf = 0.176, sup = 0.01
# {whole milk, other vegetables} ---> {domestic eggs}:  conf = 0.164, sup = 0.012
# {domestic eggs, other vegetables} ---> {whole milk}:  conf = 0.553, sup = 0.012
# {domestic eggs, whole milk} ---> {other vegetables}:  conf = 0.41, sup = 0.012
# {domestic eggs} ---> {whole milk, other vegetables}:  conf = 0.194, sup = 0.012

# %%
# selecting those that are frequent items -  using FP-Growth
Fi_fp, Frequent_items_fp = fpgrowth(dataset, min_support=0.04, verbose=True)
# Out:
# {citrus fruit}:  sup = 0.083
# {margarine}:  sup = 0.059
# {yogurt}:  sup = 0.14
# {whole milk, yogurt}:  sup = 0.056
# {other vegetables, yogurt}:  sup = 0.043
# {tropical fruit}:  sup = 0.105
# {whole milk, tropical fruit}:  sup = 0.042
# {coffee}:  sup = 0.058
# {whole milk}:  sup = 0.256
# {pip fruit}:  sup = 0.076
# {other vegetables}:  sup = 0.193
# {whole milk, other vegetables}:  sup = 0.075
# {butter}:  sup = 0.055
# {rolls/buns}:  sup = 0.184
# {other vegetables, rolls/buns}:  sup = 0.043
# {whole milk, rolls/buns}:  sup = 0.057
# {bottled beer}:  sup = 0.081
# {bottled water}:  sup = 0.111
# {chocolate}:  sup = 0.05
# {white bread}:  sup = 0.042
# {curd}:  sup = 0.053
# {beef}:  sup = 0.052
# {soda}:  sup = 0.174
# {whole milk, soda}:  sup = 0.04
# {frankfurter}:  sup = 0.059
# {chicken}:  sup = 0.043
# {newspapers}:  sup = 0.08
# {fruit/vegetable juice}:  sup = 0.072
# {pastry}:  sup = 0.089
# {root vegetables}:  sup = 0.109
# {other vegetables, root vegetables}:  sup = 0.047
# {whole milk, root vegetables}:  sup = 0.049
# {canned beer}:  sup = 0.078
# {sausage}:  sup = 0.094
# {shopping bags}:  sup = 0.099
# {brown bread}:  sup = 0.065
# {napkins}:  sup = 0.052
# {whipped/sour cream}:  sup = 0.072
# {pork}:  sup = 0.058
# {domestic eggs}:  sup = 0.063
# {frozen vegetables}:  sup = 0.048

# %%
#listing association rules derived
Association_fp = generate_rules(Fi_fp, Frequent_items_fp, min_confidence=0.4, verbose=True)
# Out:
# {yogurt} ---> {whole milk}:  conf = 0.402, sup = 0.056
# {tropical fruit} ---> {whole milk}:  conf = 0.403, sup = 0.042
# {root vegetables} ---> {other vegetables}:  conf = 0.435, sup = 0.047
# {root vegetables} ---> {whole milk}:  conf = 0.449, sup = 0.049

# %%
# selecting those that are frequent items -  using FP-Growth
Fi_fp, Frequent_items_fp = fpgrowth(dataset, min_support=0.06, verbose=True)
# Out:
# {citrus fruit}:  sup = 0.083
# {yogurt}:  sup = 0.14
# {tropical fruit}:  sup = 0.105
# {whole milk}:  sup = 0.256
# {pip fruit}:  sup = 0.076
# {other vegetables}:  sup = 0.193
# {whole milk, other vegetables}:  sup = 0.075
# {rolls/buns}:  sup = 0.184
# {bottled beer}:  sup = 0.081
# {bottled water}:  sup = 0.111
# {soda}:  sup = 0.174
# {newspapers}:  sup = 0.08
# {fruit/vegetable juice}:  sup = 0.072
# {pastry}:  sup = 0.089
# {root vegetables}:  sup = 0.109
# {canned beer}:  sup = 0.078
# {sausage}:  sup = 0.094
# {shopping bags}:  sup = 0.099
# {brown bread}:  sup = 0.065
# {whipped/sour cream}:  sup = 0.072
# {domestic eggs}:  sup = 0.063

# %%
#listing association rules derived
Association_fp = generate_rules(Fi_fp, Frequent_items_fp, min_confidence=0.2, verbose=True)
# Out:
# {other vegetables} ---> {whole milk}:  conf = 0.387, sup = 0.075
# {whole milk} ---> {other vegetables}:  conf = 0.293, sup = 0.075

# %% [markdown]
# <h3>Inference - fp_growth</h3>
# <b>Stats</b>
# min_support - 0.01, min_confidence 0.1 -->  many associations<br>
# min_support - 0.04, min_confidence- 0.4 --> 4 associations<br>
# min_support - 0.06, min_confidence 0.2 --> 2 associations<br>
#
# As min_support and min_confidence were incresed, we see decrese in number of associations.
# Also, {other vegetables} ---> {whole milk}, {root vegetables} ---> {other vegetables} and {yogurt} ---> {whole milk} seems to be favorite combination from grocery shop.

# %% [markdown]
# # Part 3 - Interest Factor

# %%
# Using either Apriori or FPgrowth algorithm with 2% support and 30% confidence to generate the rules 

Fi,Frequent_items = apriori(dataset, min_support=0.02, verbose=True)
# Out:
# {meat}:  sup = 0.026
# {sliced cheese}:  sup = 0.025
# {onions}:  sup = 0.031
# {frozen meals}:  sup = 0.028
# {specialty chocolate}:  sup = 0.03
# {frozen vegetables}:  sup = 0.048
# {ice cream}:  sup = 0.025
# {oil}:  sup = 0.028
# {chewing gum}:  sup = 0.021
# {ham}:  sup = 0.026
# {cat food}:  sup = 0.023
# {hard cheese}:  sup = 0.025
# {misc. beverages}:  sup = 0.028
# {domestic eggs}:  sup = 0.063
# {dessert}:  sup = 0.037
# {grapes}:  sup = 0.022
# {whipped/sour cream}:  sup = 0.072
# {pork}:  sup = 0.058
# {berries}:  sup = 0.033
# {napkins}:  sup = 0.052
# {hygiene articles}:  sup = 0.033
# {hamburger meat}:  sup = 0.033
# {beverages}:  sup = 0.026
# {shopping bags}:  sup = 0.099
# {brown bread}:  sup = 0.065
# {sausage}:  sup = 0.094
# {canned beer}:  sup = 0.078
# {waffles}:  sup = 0.038
# {salty snack}:  sup = 0.038
# {root vegetables}:  sup = 0.109
# {candy}:  sup = 0.03
# {pastry}:  sup = 0.089
# {butter milk}:  sup = 0.028
# {specialty bar}:  sup = 0.027
# {sugar}:  sup = 0.034
# {newspapers}:  sup = 0.08
# {fruit/vegetable juice}:  sup = 0.072
# {chicken}:  sup = 0.043
# {soda}:  sup = 0.174
# {frankfurter}:  sup = 0.059
# {beef}:  sup = 0.052
# {curd}:  sup = 0.053
# {white bread}:  sup = 0.042
# {chocolate}:  sup = 0.05
# {bottled water}:  sup = 0.111
# {bottled beer}:  sup = 0.081
# {UHT-milk}:  sup = 0.033
# {rolls/buns}:  sup = 0.184
# {butter}:  sup = 0.055
# {other vegetables}:  sup = 0.193
# {long life bakery product}:  sup = 0.037
# {pip fruit}:  sup = 0.076
# {cream cheese}:  sup = 0.04
# {whole milk}:  sup = 0.256
# {yogurt}:  sup = 0.14
# {tropical fruit}:  sup = 0.105
# {coffee}:  sup = 0.058
# {margarine}:  sup = 0.059
# {citrus fruit}:  sup = 0.083
# {whipped/sour cream, yogurt}:  sup = 0.021
# {other vegetables, yogurt}:  sup = 0.043
# {other vegetables, pip fruit}:  sup = 0.026
# {other vegetables, pastry}:  sup = 0.023
# {other vegetables, shopping bags}:  sup = 0.023
# {sausage, other vegetables}:  sup = 0.027
# {bottled beer, whole milk}:  sup = 0.02
# {whole milk, shopping bags}:  sup = 0.025
# {citrus fruit, other vegetables}:  sup = 0.029
# {whole milk, fruit/vegetable juice}:  sup = 0.027
# {frankfurter, whole milk}:  sup = 0.021
# {whole milk, newspapers}:  sup = 0.027
# {margarine, whole milk}:  sup = 0.024
# {tropical fruit, pip fruit}:  sup = 0.02
# {whole milk, pip fruit}:  sup = 0.03
# {whole milk, rolls/buns}:  sup = 0.057
# {whole milk, beef}:  sup = 0.021
# {sausage, whole milk}:  sup = 0.03
# {frozen vegetables, whole milk}:  sup = 0.02
# {pastry, rolls/buns}:  sup = 0.021
# {other vegetables, fruit/vegetable juice}:  sup = 0.021
# {domestic eggs, other vegetables}:  sup = 0.022
# {butter, other vegetables}:  sup = 0.02
# {yogurt, rolls/buns}:  sup = 0.034
# {bottled water, soda}:  sup = 0.029
# {tropical fruit, soda}:  sup = 0.021
# {yogurt, soda}:  sup = 0.027
# {whole milk, pastry}:  sup = 0.033
# {yogurt, root vegetables}:  sup = 0.026
# {brown bread, whole milk}:  sup = 0.025
# {domestic eggs, whole milk}:  sup = 0.03
# {pastry, soda}:  sup = 0.021
# {whole milk, soda}:  sup = 0.04
# {other vegetables, soda}:  sup = 0.033
# {whole milk, pork}:  sup = 0.022
# {pork, other vegetables}:  sup = 0.022
# {whole milk, whipped/sour cream}:  sup = 0.032
# {whipped/sour cream, other vegetables}:  sup = 0.029
# {whole milk, root vegetables}:  sup = 0.049
# {bottled water, rolls/buns}:  sup = 0.024
# {soda, shopping bags}:  sup = 0.025
# {sausage, rolls/buns}:  sup = 0.031
# {sausage, soda}:  sup = 0.024
# {tropical fruit, rolls/buns}:  sup = 0.025
# {tropical fruit, root vegetables}:  sup = 0.021
# {other vegetables, root vegetables}:  sup = 0.047
# {rolls/buns, root vegetables}:  sup = 0.024
# {rolls/buns, soda}:  sup = 0.038
# {citrus fruit, yogurt}:  sup = 0.022
# {citrus fruit, whole milk}:  sup = 0.031
# {whole milk, tropical fruit}:  sup = 0.042
# {bottled water, yogurt}:  sup = 0.023
# {whole milk, bottled water}:  sup = 0.034
# {whole milk, curd}:  sup = 0.026
# {tropical fruit, other vegetables}:  sup = 0.036
# {other vegetables, bottled water}:  sup = 0.025
# {other vegetables, rolls/buns}:  sup = 0.043
# {whole milk, yogurt}:  sup = 0.056
# {butter, whole milk}:  sup = 0.028
# {whole milk, other vegetables}:  sup = 0.075
# {tropical fruit, yogurt}:  sup = 0.029
# {whole milk, other vegetables, yogurt}:  sup = 0.022
# {whole milk, other vegetables, root vegetables}:  sup = 0.023

# %%
Association = generate_rules(Fi, Frequent_items, min_confidence=0.3, verbose=True)
# Out:
# {yogurt} ---> {other vegetables}:  conf = 0.311, sup = 0.043
# {pip fruit} ---> {other vegetables}:  conf = 0.345, sup = 0.026
# {citrus fruit} ---> {other vegetables}:  conf = 0.349, sup = 0.029
# {fruit/vegetable juice} ---> {whole milk}:  conf = 0.368, sup = 0.027
# {frankfurter} ---> {whole milk}:  conf = 0.348, sup = 0.021
# {newspapers} ---> {whole milk}:  conf = 0.343, sup = 0.027
# {margarine} ---> {whole milk}:  conf = 0.413, sup = 0.024
# {pip fruit} ---> {whole milk}:  conf = 0.398, sup = 0.03
# {rolls/buns} ---> {whole milk}:  conf = 0.308, sup = 0.057
# {beef} ---> {whole milk}:  conf = 0.405, sup = 0.021
# {sausage} ---> {whole milk}:  conf = 0.318, sup = 0.03
# {frozen vegetables} ---> {whole milk}:  conf = 0.425, sup = 0.02
# {domestic eggs} ---> {other vegetables}:  conf = 0.351, sup = 0.022
# {butter} ---> {other vegetables}:  conf = 0.361, sup = 0.02
# {pastry} ---> {whole milk}:  conf = 0.374, sup = 0.033
# {brown bread} ---> {whole milk}:  conf = 0.389, sup = 0.025
# {domestic eggs} ---> {whole milk}:  conf = 0.473, sup = 0.03
# {pork} ---> {whole milk}:  conf = 0.384, sup = 0.022
# {pork} ---> {other vegetables}:  conf = 0.376, sup = 0.022
# {whipped/sour cream} ---> {whole milk}:  conf = 0.45, sup = 0.032
# {whipped/sour cream} ---> {other vegetables}:  conf = 0.403, sup = 0.029
# {root vegetables} ---> {whole milk}:  conf = 0.449, sup = 0.049
# {sausage} ---> {rolls/buns}:  conf = 0.326, sup = 0.031
# {root vegetables} ---> {other vegetables}:  conf = 0.435, sup = 0.047
# {citrus fruit} ---> {whole milk}:  conf = 0.369, sup = 0.031
# {tropical fruit} ---> {whole milk}:  conf = 0.403, sup = 0.042
# {bottled water} ---> {whole milk}:  conf = 0.311, sup = 0.034
# {curd} ---> {whole milk}:  conf = 0.49, sup = 0.026
# {tropical fruit} ---> {other vegetables}:  conf = 0.342, sup = 0.036
# {yogurt} ---> {whole milk}:  conf = 0.402, sup = 0.056
# {butter} ---> {whole milk}:  conf = 0.497, sup = 0.028
# {other vegetables} ---> {whole milk}:  conf = 0.387, sup = 0.075
# {other vegetables, yogurt} ---> {whole milk}:  conf = 0.513, sup = 0.022
# {whole milk, yogurt} ---> {other vegetables}:  conf = 0.397, sup = 0.022
# {other vegetables, root vegetables} ---> {whole milk}:  conf = 0.489, sup = 0.023
# {whole milk, root vegetables} ---> {other vegetables}:  conf = 0.474, sup = 0.023
# {whole milk, other vegetables} ---> {root vegetables}:  conf = 0.31, sup = 0.023

# %%
# a function to calculate interest factor/lift 

def lift(item1: frozenset, item2: frozenset, Frequent_items: dict): 
    union_of_items = Frequent_items[frozenset().union(item1, item2)]
    res = union_of_items/(Frequent_items[item1]*Frequent_items[item2])
    return res

# %%
#calculating lift for few examples
lift(frozenset({'pastry'}), frozenset({'whole milk'}), Frequent_items)
# Out:
# 1.4625865499403101

# %%
#calculating lift for few examples
lift(frozenset({'yogurt'}), frozenset({'other vegetables'}), Frequent_items)
# Out:
# 1.6084565723294046

# %%
# a function to generate a dataframe listing the interest factor, confidence and support for all the associations/rules we have 
import pandas as pd
result = []
def Summarize_Association(rules, items):
    #loop through all the rules and calculate respective support, confidence and interest_factor
    for r in rules:
        item1, item2, confidence = r
        interestfac = lift(item1, item2, items)
        res = {"association":(r[0], r[1]), "support": Frequent_items[frozenset().union(item1, item2)], "confidence": confidence, "interest_factor": interestfac}
        result.append(res)
    dataframe = pd.DataFrame(result, columns=titles)
    return dataframe

# %%
# listing the interest factor, confidence and support for all the associations/rules we have  
results = Summarize_Association(Association, Frequent_items)
results
# Out:
#                                           association   support  confidence  \
# 0                      ((yogurt), (other vegetables))  0.043416    0.311224
# 1                   ((pip fruit), (other vegetables))  0.026131    0.345430
# 2                ((citrus fruit), (other vegetables))  0.028876    0.348894
# 3             ((fruit/vegetable juice), (whole milk))  0.026640    0.368495
# 4                       ((frankfurter), (whole milk))  0.020539    0.348276
# 5                        ((newspapers), (whole milk))  0.027351    0.342675
# 6                         ((margarine), (whole milk))  0.024199    0.413194
# 7                         ((pip fruit), (whole milk))  0.030097    0.397849
# 8                        ((rolls/buns), (whole milk))  0.056634    0.307905
# 9                              ((beef), (whole milk))  0.021251    0.405039
# 10                          ((sausage), (whole milk))  0.029893    0.318182
# 11                ((frozen vegetables), (whole milk))  0.020437    0.424947
# 12              ((domestic eggs), (other vegetables))  0.022267    0.350962
# 13                     ((butter), (other vegetables))  0.020031    0.361468
# 14                           ((pastry), (whole milk))  0.033249    0.373714
# 15                      ((brown bread), (whole milk))  0.025216    0.388715
# 16                    ((domestic eggs), (whole milk))  0.029995    0.472756
# 17                             ((pork), (whole milk))  0.022166    0.384480
# 18                       ((pork), (other vegetables))  0.021657    0.375661
# 19               ((whipped/sour cream), (whole milk))  0.032232    0.449645
# 20         ((whipped/sour cream), (other vegetables))  0.028876    0.402837
# 21                  ((root vegetables), (whole milk))  0.048907    0.448694
# 22                          ((sausage), (rolls/buns))  0.030605    0.325758
# 23            ((root vegetables), (other vegetables))  0.047382    0.434701
# 24                     ((citrus fruit), (whole milk))  0.030503    0.368550
# 25                   ((tropical fruit), (whole milk))  0.042298    0.403101
# 26                    ((bottled water), (whole milk))  0.034367    0.310948
# 27                             ((curd), (whole milk))  0.026131    0.490458
# 28             ((tropical fruit), (other vegetables))  0.035892    0.342054
# 29                           ((yogurt), (whole milk))  0.056024    0.401603
# 30                           ((butter), (whole milk))  0.027555    0.497248
# 31                 ((other vegetables), (whole milk))  0.074835    0.386758
# 32         ((other vegetables, yogurt), (whole milk))  0.022267    0.512881
# 33         ((whole milk, yogurt), (other vegetables))  0.022267    0.397459
# 34  ((other vegetables, root vegetables), (whole m...  0.023183    0.489270
# 35  ((whole milk, root vegetables), (other vegetab...  0.023183    0.474012
# 36  ((whole milk, other vegetables), (root vegetab...  0.023183    0.309783
#
#     interest_factor
# 0          1.608457
# 1          1.785237
# 2          1.803140
# 3          1.442160
# 4          1.363029
# 5          1.341110
# 6          1.617098
# 7          1.557043
# 8          1.205032
# 9          1.585180
# 10         1.245252
# 11         1.663094
# 12         1.813824
# 13         1.868122
# 14         1.462587
# 15         1.521293
# 16         1.850203
# 17         1.504719
# 18         1.941476
# 19         1.759754
# 20         2.081924
# 21         1.756031
# 22         1.771048
# 23         2.246605
# 24         1.442377
# 25         1.577595
# 26         1.216940
# 27         1.919481
# 28         1.767790
# 29         1.571735
# 30         1.946053
# 31         1.513634
# 32         2.007235
# 33         2.054131
# 34         1.914833
# 35         2.449770
# 36         2.842082

# %%
# Sorting results in descending order by support.
result_by_support = results.sort_values('support',ascending= False)
result_by_support.head()
# Out:
#                                 association   support  confidence  \
# 31       ((other vegetables), (whole milk))  0.074835    0.386758
# 8              ((rolls/buns), (whole milk))  0.056634    0.307905
# 29                 ((yogurt), (whole milk))  0.056024    0.401603
# 21        ((root vegetables), (whole milk))  0.048907    0.448694
# 23  ((root vegetables), (other vegetables))  0.047382    0.434701
#
#     interest_factor
# 31         1.513634
# 8          1.205032
# 29         1.571735
# 21         1.756031
# 23         2.246605

# %%
# Sorting results in descending order by confidence.
result_by_confidence = results.sort_values('confidence',ascending= False)
result_by_confidence.head()
# Out:
#                                           association   support  confidence  \
# 32         ((other vegetables, yogurt), (whole milk))  0.022267    0.512881
# 30                           ((butter), (whole milk))  0.027555    0.497248
# 27                             ((curd), (whole milk))  0.026131    0.490458
# 34  ((other vegetables, root vegetables), (whole m...  0.023183    0.489270
# 35  ((whole milk, root vegetables), (other vegetab...  0.023183    0.474012
#
#     interest_factor
# 32         2.007235
# 30         1.946053
# 27         1.919481
# 34         1.914833
# 35         2.449770

# %%
# Sorting results in descending order by interest_factor. 
result_by_interest_factor = results.sort_values('interest_factor',ascending= False)
result_by_interest_factor.head()
# Out:
#                                           association   support  confidence  \
# 36  ((whole milk, other vegetables), (root vegetab...  0.023183    0.309783
# 35  ((whole milk, root vegetables), (other vegetab...  0.023183    0.474012
# 23            ((root vegetables), (other vegetables))  0.047382    0.434701
# 20         ((whipped/sour cream), (other vegetables))  0.028876    0.402837
# 33         ((whole milk, yogurt), (other vegetables))  0.022267    0.397459
#
#     interest_factor
# 36         2.842082
# 35         2.449770
# 23         2.246605
# 20         2.081924
# 33         2.054131

# %% [markdown]
# After sorting the rules in descending order by support, confidence, and interest factor separately we do not see anything common with respect to either support & confidence or support and interest_factor.<br>
# But, we have (whole milk, root vegetables), (other vegetables) combination common with confidence and interest_factor.
